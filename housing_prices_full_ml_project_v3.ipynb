# %% [markdown]
# # **Exaustive machine learning project (housing prices) : exploration and predictions**
#
# > In this first section we just load and format our train and test data, and we define a funtion and will allow us to do polynomial regression easily

# %%
# !pip install -q optuna
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.4 MB/s eta 0:00:00

# %%
# !pip install -q catboost
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.8 MB/s eta 0:00:00

# %%
# !pip install -q skoptimize
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 4.0 MB/s eta 0:00:00

# %%
import pandas as pd
from math import nan
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from catboost import CatBoostRegressor
from catboost import CatBoostRegressor, Pool

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNetCV
from sklearn.neighbors import KNeighborsRegressor

from sklearn.decomposition import PCA

import optuna

from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
X_final_test_before_cleaning = pd.read_csv('test.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
id_serie = X_final_test_before_cleaning.Id

# %%
df = pd.concat([df, X_final_test_before_cleaning], axis = 0)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ       706.0          Unf         0.0      150.0        856.0
# 1          ALQ       978.0          Unf         0.0      284.0       1262.0
# 2          GLQ       486.0          Unf         0.0      434.0        920.0
# 3          ALQ       216.0          Unf         0.0      540.0        756.0
# 4          GLQ       655.0          Unf         0.0      490.0       1145.0
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710           1.0           0.0         2         1             3
# 1       1262           0.0           1.0         2         0             3
# 2       1786           1.0           0.0         2         1             3
# 3       1717           1.0           0.0         1         0             3
# 4       2198           1.0           0.0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn         2.0       548.0         TA
# 1     Attchd       1976.0          RFn         2.0       460.0         TA
# 2     Attchd       2001.0          RFn         2.0       608.0         TA
# 3     Detchd       1998.0          Unf         3.0       642.0         TA
# 4     Attchd       2000.0          RFn         3.0       836.0         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal   208500.0
# 1       WD        Normal   181500.0
# 2       WD        Normal   223500.0
# 3       WD       Abnorml   140000.0
# 4       WD        Normal   250000.0

# %%
def get_best_regression_degree(data_X, data_y, model, range=range(1, 100)):
  scores = pd.Series(index=range)
  for d in range :
    print('\n degree in process : ', d)
    polynomial_converter = PolynomialFeatures(degree=d, include_bias=False)
    poly_data_X = polynomial_converter.fit_transform(data_X)
    print('number of features : ', np.shape(poly_data_X)[1])
    score = cross_val_score(model, poly_data_X, data_y, cv=5, scoring='neg_mean_absolute_percentage_error').mean()
    scores[d]=score
    print('mean_absolute_percentage_error (mean CV): ', -score)
    model.fit(poly_data_X, data_y)
    print('mean_absolute_percentage_error (on the training set) : ', mean_absolute_percentage_error(data_y, model.predict(poly_data_X)))

  return np.argmax(scores), np.max(score)

# %% [markdown]
# # **Data Preprocessing**
#
# In this section, we
# - put the features into the right data structure
# - deal with missing values (replace or drop)
# - Data Preparation : create different versions of the dataset to apply the models flexibly later (X_train, X_test, y_train, y_test, scaled features, only numerical features, etc)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ***useful quality dict***

# %%
Qual_dict = {
    'Po' : 0,
    'Fa' : 1,
    'TA' : 2,
    'Gd' : 3,
    'Ex' : 4
}

# %% [markdown]
# ### num to cat

# %% [markdown]
# **MSSubClass** : Num to Cat
#
# This variable identifies the type of dwelling involved in the sale.

# %%
df.MSSubClass.value_counts()
# Out:
# MSSubClass
# 20     1079
# 60      575
# 50      287
# 120     182
# 30      139
# 70      128
# 160     128
# 80      118
# 90      109
# 190      61
# 85       48
# 75       23
# 45       18
# 180      17
# 40        6
# 150       1
# Name: count, dtype: int64

# %%
MSSubClass_dict =  {20  :  '1-STORY 1946 & NEWER ALL STYLES',
                    30  :  '1-STORY 1945 & OLDER',
                    40  :  '1-STORY W/FINISHED ATTIC ALL AGES',
                    45  :  '1-1/2 STORY - UNFINISHED ALL AGES',
                    50  :  '1-1/2 STORY FINISHED ALL AGES',
                    60  :  '2-STORY 1946 & NEWER',
                    70  :  '2-STORY 1945 & OLDER',
                    75  :  '2-1/2 STORY ALL AGES',
                    80  :  'SPLIT OR MULTI-LEVEL',
                    85  :  'SPLIT FOYER',
                    90  :  'DUPLEX - ALL STYLES AND AGES',
                    120  :  '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
                    150  :  '1-1/2 STORY PUD - ALL AGES',
                    160  :  '2-STORY PUD - 1946 & NEWER',
                    180  :  'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
                    190  :  '2 FAMILY CONVERSION - ALL STYLES AND AGES'
                    }

df['MSSubClass'] = df['MSSubClass'].apply(lambda n: MSSubClass_dict[n])
df.MSSubClass.value_counts()
# Out:
# MSSubClass
# 1-STORY 1946 & NEWER ALL STYLES                          1079
# 2-STORY 1946 & NEWER                                      575
# 1-1/2 STORY FINISHED ALL AGES                             287
# 1-STORY PUD (Planned Unit Development) - 1946 & NEWER     182
# 1-STORY 1945 & OLDER                                      139
# 2-STORY 1945 & OLDER                                      128
# 2-STORY PUD - 1946 & NEWER                                128
# SPLIT OR MULTI-LEVEL                                      118
# DUPLEX - ALL STYLES AND AGES                              109
# 2 FAMILY CONVERSION - ALL STYLES AND AGES                  61
# SPLIT FOYER                                                48
# 2-1/2 STORY ALL AGES                                       23
# 1-1/2 STORY - UNFINISHED ALL AGES                          18
# PUD - MULTILEVEL - INCL SPLIT LEV/FOYER                    17
# 1-STORY W/FINISHED ATTIC ALL AGES                           6
# 1-1/2 STORY PUD - ALL AGES                                  1
# Name: count, dtype: int64

# %%
# MSSubClass_dict =  {20  :  'A',
#                     30  :  'B',
#                     40  :  'C',
#                     45  :  'D',
#                     50  :  'E',
#                     60  :  'F',
#                     70  :  'G',
#                     75  :  'H',
#                     80  :  'I',
#                     85  :  'J',
#                     90  :  'K',
#                     120  :  'L',
#                     150  :  'M',
#                     160  :  'N',
#                     180  :  'O',
#                     190  :  'P'
#                     }

# df['MSSubClass'] = df['MSSubClass'].apply(lambda n: MSSubClass_dict[n])
# df.MSSubClass.value_counts()

# %% [markdown]
# ### cat to bin

# %% [markdown]
# **Street** : Cat to Bin
#
# This variable represents the type of road access to property (material)

# %%
df.Street.value_counts()
# Out:
# Street
# Pave    2907
# Grvl      12
# Name: count, dtype: int64

# %%
df.Street = df.Street.apply(lambda a: 0 if a=='Pave' else 1)
df.Street.value_counts()
# Out:
# Street
# 0    2907
# 1      12
# Name: count, dtype: int64

# %% [markdown]
# Type of alley access to property (material)

# %%
df.Alley.value_counts()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %%
df.Alley = df.Alley.fillna('NA')
df.Alley.value_counts()
# Out:
# Alley
# NA      2721
# Grvl     120
# Pave      78
# Name: count, dtype: int64

# %% [markdown]
# **CentralAir** : Cat to Bin
#
# This variable represents central air conditioning

# %%
df.CentralAir.value_counts()
# Out:
# CentralAir
# Y    2723
# N     196
# Name: count, dtype: int64

# %%
df['CentralAir'] = df['CentralAir'].apply(lambda a: 0 if a=='N' else 1)
df.CentralAir.value_counts()
# Out:
# CentralAir
# 1    2723
# 0     196
# Name: count, dtype: int64

# %% [markdown]
# ### cat to num

# %% [markdown]
# **LotShape** : name change (from LotShape to LotIrregularity)
#
# **LotIrregularity** : Cat to Num

# %%
df.LotShape.value_counts()
# Out:
# LotShape
# Reg    1859
# IR1     968
# IR2      76
# IR3      16
# Name: count, dtype: int64

# %%
LotShape_dict = {
    'Reg' : 0,
    'IR1' : 1,
    'IR2' : 2,
    'IR3' : 3
}

df['LotIrregularity'] = df.LotShape.apply(lambda a: LotShape_dict[a])
df.drop('LotShape', axis=1)
df = df.drop('LotShape', axis=1)
df['LotIrregularity'].value_counts()
# Out:
# LotIrregularity
# 0    1859
# 1     968
# 2      76
# 3      16
# Name: count, dtype: int64

# %% [markdown]
# **LandSlope** : Cat to Num

# %%
df.LandSlope.value_counts()
# Out:
# LandSlope
# Gtl    2778
# Mod     125
# Sev      16
# Name: count, dtype: int64

# %%
LandSlope_dict = {
    'Gtl' : 1,
    'Mod' : 2,
    'Sev' : 3
}

df['LandSlope'] = df.LandSlope.apply(lambda a: LandSlope_dict[a])
df['LandSlope'].value_counts()
# Out:
# LandSlope
# 1    2778
# 2     125
# 3      16
# Name: count, dtype: int64

# %% [markdown]
# **ExterQual** : Cat to Num

# %%
df.ExterQual.value_counts()
# Out:
# ExterQual
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: count, dtype: int64

# %%
df['ExterQual'] = df['ExterQual'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df.ExterQual.value_counts()
# Out:
# ExterQual
# 2    1798
# 3     979
# 4     107
# 1      35
# Name: count, dtype: int64

# %% [markdown]
# **ExterCond** : Cat to Num

# %%
df.ExterCond.value_counts()
# Out:
# ExterCond
# TA    2538
# Gd     299
# Fa      67
# Ex      12
# Po       3
# Name: count, dtype: int64

# %%
df['ExterCond'] = df['ExterCond'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df.ExterCond.value_counts()
# Out:
# ExterCond
# 2    2538
# 3     299
# 1      67
# 4      12
# 0       3
# Name: count, dtype: int64

# %% [markdown]
# **HeatingQC** : Cat to Num

# %%
df.HeatingQC.value_counts()
# Out:
# HeatingQC
# Ex    1493
# TA     857
# Gd     474
# Fa      92
# Po       3
# Name: count, dtype: int64

# %%
df['HeatingQC'] = df['HeatingQC'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df.HeatingQC.value_counts()
# Out:
# HeatingQC
# 4    1493
# 2     857
# 3     474
# 1      92
# 0       3
# Name: count, dtype: int64

# %% [markdown]
# **KitchenQual** : Cat to Num

# %%
df.KitchenQual.value_counts()
# Out:
# KitchenQual
# TA    1492
# Gd    1151
# Ex     205
# Fa      70
# Name: count, dtype: int64

# %%
df['KitchenQual'] = df['KitchenQual'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df.KitchenQual.value_counts()
# Out:
# KitchenQual
# 2.0    1492
# 3.0    1151
# 4.0     205
# 1.0      70
# Name: count, dtype: int64

# %% [markdown]
# **FireplaceQu** : Cat to Num

# %%
df.FireplaceQu.value_counts()
# Out:
# FireplaceQu
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: count, dtype: int64

# %%
df['FireplaceQu'] = df['FireplaceQu'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df['FireplaceQu'] = df['FireplaceQu'].fillna(-1)
df.FireplaceQu.value_counts()
# Out:
# FireplaceQu
# -1.0    1420
#  3.0     744
#  2.0     592
#  1.0      74
#  0.0      46
#  4.0      43
# Name: count, dtype: int64

# %% [markdown]
# ### about basement

# %% [markdown]
# **BsmtQual** : Cat to Num

# %%
df.BsmtQual.value_counts()
# Out:
# BsmtQual
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: count, dtype: int64

# %%
df['BsmtQual'] = df['BsmtQual'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df['BsmtQual'] = df['BsmtQual'].fillna(-1)
df.BsmtQual.value_counts()
# Out:
# BsmtQual
#  2.0    1283
#  3.0    1209
#  4.0     258
#  1.0      88
# -1.0      81
# Name: count, dtype: int64

# %% [markdown]
# **BsmtCond** : Cat to Num

# %%
df.BsmtCond.value_counts()
# Out:
# BsmtCond
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: count, dtype: int64

# %%
df['BsmtCond'] = df['BsmtCond'].apply(lambda a: Qual_dict[a] if type(a)==str else nan)
df['BsmtCond'] = df['BsmtCond'].fillna(-1)
df.BsmtCond.value_counts()
# Out:
# BsmtCond
#  2.0    2606
#  3.0     122
#  1.0     104
# -1.0      82
#  0.0       5
# Name: count, dtype: int64

# %% [markdown]
# **BsmtExposureExist** : variable created from BsmtExposure 'No' category

# %%
df.BsmtExposure.value_counts()
# Out:
# BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: count, dtype: int64

# %%
BsmtExposure_array = np.ones(len(df))
BsmtExposure_array[df[df['BsmtExposure']=='No'].index]=0
df['BsmtExposureExist']=BsmtExposure_array.astype(int)
df.BsmtExposureExist.value_counts()
# Out:
# BsmtExposureExist
# 1    1633
# 0    1286
# Name: count, dtype: int64

# %% [markdown]
# **BsmtExist** : variable created from BsmtCond NaN's

# %%
BsmtExist_array = np.ones(len(df))
BsmtExist_array[df[df['BsmtFinType1'].isnull()].index]=0
df['BsmtExist']=BsmtExist_array.astype(int)
df.BsmtExist.value_counts()
# Out:
# BsmtExist
# 1    2840
# 0      79
# Name: count, dtype: int64

# %% [markdown]
# **BsmtExposure** : Cat to Num

# %%
df.BsmtExposure.value_counts()
# Out:
# BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: count, dtype: int64

# %%
BsmtExposure_dict = {
    'Gd' : 3,
    'Av' : 2,
    'Mn' : 1,
    'No' : 0
}

df['BsmtExposure'] = df['BsmtExposure'].apply(lambda a: BsmtExposure_dict[a] if type(a)==str else nan)
df['BsmtExposure'] = df['BsmtExposure'].fillna(-1)
df.BsmtExposure.value_counts()
# Out:
# BsmtExposure
#  0.0    1904
#  2.0     418
#  3.0     276
#  1.0     239
# -1.0      82
# Name: count, dtype: int64

# %% [markdown]
# ### about garage

# %% [markdown]
# **GarageFinish** : Cat to Num

# %%
df.GarageFinish.value_counts()
# Out:
# GarageFinish
# Unf    1230
# RFn     811
# Fin     719
# Name: count, dtype: int64

# %%
GarageFinish_dict = {
    'Unf' : 1,
    'RFn' : 2,
    'Fin' : 3
}

df['GarageFinish'] = df['GarageFinish'].apply(lambda a: GarageFinish_dict[a] if type(a)==str else -1)
df.GarageFinish.value_counts()
# Out:
# GarageFinish
#  1    1230
#  2     811
#  3     719
# -1     159
# Name: count, dtype: int64

# %% [markdown]
# **GarageQual** : Cat to Num

# %%
df.GarageQual.value_counts()
# Out:
# GarageQual
# TA    2604
# Fa     124
# Gd      24
# Po       5
# Ex       3
# Name: count, dtype: int64

# %%
GarageQual_dict = {
    'Po' : 0,
    'Fa' : 1,
    'TA' : 2,
    'Gd' : 3,
    'Ex' : 4
}

df['GarageQual'] = df['GarageQual'].apply(lambda a: GarageQual_dict[a] if type(a)==str else -1)
df.GarageQual.value_counts()
# Out:
# GarageQual
#  2    2604
# -1     159
#  1     124
#  3      24
#  0       5
#  4       3
# Name: count, dtype: int64

# %% [markdown]
# **GarageCond** : Cat to Num

# %%
df.GarageCond.value_counts()
# Out:
# GarageCond
# TA    2654
# Fa      74
# Gd      15
# Po      14
# Ex       3
# Name: count, dtype: int64

# %%
GarageCond_dict = {
    'Po' : 0,
    'Fa' : 1,
    'TA' : 2,
    'Gd' : 3,
    'Ex' : 4
}

df['GarageCond'] = df['GarageCond'].apply(lambda a: GarageCond_dict[a] if type(a)==str else -1)
df.GarageCond.value_counts()
# Out:
# GarageCond
#  2    2654
# -1     159
#  1      74
#  3      15
#  0      14
#  4       3
# Name: count, dtype: int64

# %% [markdown]
# **GarageExist** : variable created from GarageType NaN values

# %%
GarageExist_array = np.ones(len(df))
GarageExist_array[df[df['GarageType'].isnull()].index]=0
df['GarageExist']=GarageExist_array.astype(int)
df.GarageExist.value_counts()
# Out:
# GarageExist
# 1    2767
# 0     152
# Name: count, dtype: int64

# %% [markdown]
# ### about pool

# %% [markdown]
# **PoolExist** : variable created from PoolQC NaN values

# %%
PoolExist_array = np.ones(len(df))
PoolExist_array[df[df['PoolQC'].isnull()].index]=0
df['PoolExist']=PoolExist_array.astype(int)
df.head()
# Out:
#    Id                       MSSubClass MSZoning  LotFrontage  LotArea  Street  \
# 0   1             2-STORY 1946 & NEWER       RL         65.0     8450       0
# 1   2  1-STORY 1946 & NEWER ALL STYLES       RL         80.0     9600       0
# 2   3             2-STORY 1946 & NEWER       RL         68.0    11250       0
# 3   4             2-STORY 1945 & OLDER       RL         60.0     9550       0
# 4   5             2-STORY 1946 & NEWER       RL         84.0    14260       0
#
#   Alley LandContour Utilities LotConfig  LandSlope Neighborhood Condition1  \
# 0    NA         Lvl    AllPub    Inside          1      CollgCr       Norm
# 1    NA         Lvl    AllPub       FR2          1      Veenker      Feedr
# 2    NA         Lvl    AllPub    Inside          1      CollgCr       Norm
# 3    NA         Lvl    AllPub    Corner          1      Crawfor       Norm
# 4    NA         Lvl    AllPub       FR2          1      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea  ExterQual  ExterCond Foundation  BsmtQual  BsmtCond  \
# 0       196.0          3          2      PConc       3.0       2.0
# 1         0.0          2          2     CBlock       3.0       2.0
# 2       162.0          3          2      PConc       3.0       2.0
# 3         0.0          2          2     BrkTil       2.0       3.0
# 4       350.0          3          2      PConc       3.0       2.0
#
#    BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0           0.0          GLQ       706.0          Unf         0.0      150.0
# 1           3.0          ALQ       978.0          Unf         0.0      284.0
# 2           1.0          GLQ       486.0          Unf         0.0      434.0
# 3           0.0          ALQ       216.0          Unf         0.0      540.0
# 4           2.0          GLQ       655.0          Unf         0.0      490.0
#
#    TotalBsmtSF Heating  HeatingQC  CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0        856.0    GasA          4           1      SBrkr       856       854
# 1       1262.0    GasA          4           1      SBrkr      1262         0
# 2        920.0    GasA          4           1      SBrkr       920       866
# 3        756.0    GasA          3           1      SBrkr       961       756
# 4       1145.0    GasA          4           1      SBrkr      1145      1053
#
#    LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0             0       1710           1.0           0.0         2         1
# 1             0       1262           0.0           1.0         2         0
# 2             0       1786           1.0           0.0         2         1
# 3             0       1717           1.0           0.0         1         0
# 4             0       2198           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd Functional  \
# 0             3             1          3.0             8        Typ
# 1             3             1          2.0             6        Typ
# 2             3             1          3.0             6        Typ
# 3             3             1          3.0             7        Typ
# 4             4             1          3.0             9        Typ
#
#    Fireplaces  FireplaceQu GarageType  GarageYrBlt  GarageFinish  GarageCars  \
# 0           0         -1.0     Attchd       2003.0             2         2.0
# 1           1          2.0     Attchd       1976.0             2         2.0
# 2           1          2.0     Attchd       2001.0             2         2.0
# 3           1          3.0     Detchd       1998.0             1         3.0
# 4           1          2.0     Attchd       2000.0             2         3.0
#
#    GarageArea  GarageQual  GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0       548.0           2           2          Y           0           61
# 1       460.0           2           2          Y         298            0
# 2       608.0           2           2          Y           0           42
# 3       642.0           2           2          Y           0           35
# 4       836.0           2           2          Y         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  \
# 0              0          0            0         0    NaN   NaN         NaN
# 1              0          0            0         0    NaN   NaN         NaN
# 2              0          0            0         0    NaN   NaN         NaN
# 3            272          0            0         0    NaN   NaN         NaN
# 4              0          0            0         0    NaN   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  LotIrregularity  \
# 0        0       2    2008       WD        Normal   208500.0                0
# 1        0       5    2007       WD        Normal   181500.0                0
# 2        0       9    2008       WD        Normal   223500.0                1
# 3        0       2    2006       WD       Abnorml   140000.0                1
# 4        0      12    2008       WD        Normal   250000.0                1
#
#    BsmtExposureExist  BsmtExist  GarageExist  PoolExist
# 0                  0          1            1          0
# 1                  0          1            1          0
# 2                  0          1            1          0
# 3                  0          1            1          0
# 4                  0          1            1          0

# %% [markdown]
# **PoolQC** : Cat to Num

# %%
df.PoolQC.value_counts()
# Out:
# PoolQC
# Ex    4
# Gd    4
# Fa    2
# Name: count, dtype: int64

# %%
PoolQC_dict = {
    'Po' : 0,
    'Fa' : 1,
    'TA' : 2,
    'Gd' : 3,
    'Ex' : 4
}

df['PoolQC'] = df['PoolQC'].apply(lambda a: PoolQC_dict[a] if type(a)==str else -1)
df.PoolQC.value_counts()
# Out:
# PoolQC
# -1    2909
#  4       4
#  3       4
#  1       2
# Name: count, dtype: int64

# %% [markdown]
# ### about fence

# %%
df.Fence.value_counts()
# Out:
# Fence
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64

# %% [markdown]
# **FenceExist** :  variable created from Fence NaN values

# %%
FenceExist_array = np.ones(len(df))
FenceExist_array[df[df['Fence'].isnull()].index]=0
df['FenceExist']=FenceExist_array.astype(int)
df.head()
# Out:
#    Id                       MSSubClass MSZoning  LotFrontage  LotArea  Street  \
# 0   1             2-STORY 1946 & NEWER       RL         65.0     8450       0
# 1   2  1-STORY 1946 & NEWER ALL STYLES       RL         80.0     9600       0
# 2   3             2-STORY 1946 & NEWER       RL         68.0    11250       0
# 3   4             2-STORY 1945 & OLDER       RL         60.0     9550       0
# 4   5             2-STORY 1946 & NEWER       RL         84.0    14260       0
#
#   Alley LandContour Utilities LotConfig  LandSlope Neighborhood Condition1  \
# 0    NA         Lvl    AllPub    Inside          1      CollgCr       Norm
# 1    NA         Lvl    AllPub       FR2          1      Veenker      Feedr
# 2    NA         Lvl    AllPub    Inside          1      CollgCr       Norm
# 3    NA         Lvl    AllPub    Corner          1      Crawfor       Norm
# 4    NA         Lvl    AllPub       FR2          1      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea  ExterQual  ExterCond Foundation  BsmtQual  BsmtCond  \
# 0       196.0          3          2      PConc       3.0       2.0
# 1         0.0          2          2     CBlock       3.0       2.0
# 2       162.0          3          2      PConc       3.0       2.0
# 3         0.0          2          2     BrkTil       2.0       3.0
# 4       350.0          3          2      PConc       3.0       2.0
#
#    BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  \
# 0           0.0          GLQ       706.0          Unf         0.0      150.0
# 1           3.0          ALQ       978.0          Unf         0.0      284.0
# 2           1.0          GLQ       486.0          Unf         0.0      434.0
# 3           0.0          ALQ       216.0          Unf         0.0      540.0
# 4           2.0          GLQ       655.0          Unf         0.0      490.0
#
#    TotalBsmtSF Heating  HeatingQC  CentralAir Electrical  1stFlrSF  2ndFlrSF  \
# 0        856.0    GasA          4           1      SBrkr       856       854
# 1       1262.0    GasA          4           1      SBrkr      1262         0
# 2        920.0    GasA          4           1      SBrkr       920       866
# 3        756.0    GasA          3           1      SBrkr       961       756
# 4       1145.0    GasA          4           1      SBrkr      1145      1053
#
#    LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0             0       1710           1.0           0.0         2         1
# 1             0       1262           0.0           1.0         2         0
# 2             0       1786           1.0           0.0         2         1
# 3             0       1717           1.0           0.0         1         0
# 4             0       2198           1.0           0.0         2         1
#
#    BedroomAbvGr  KitchenAbvGr  KitchenQual  TotRmsAbvGrd Functional  \
# 0             3             1          3.0             8        Typ
# 1             3             1          2.0             6        Typ
# 2             3             1          3.0             6        Typ
# 3             3             1          3.0             7        Typ
# 4             4             1          3.0             9        Typ
#
#    Fireplaces  FireplaceQu GarageType  GarageYrBlt  GarageFinish  GarageCars  \
# 0           0         -1.0     Attchd       2003.0             2         2.0
# 1           1          2.0     Attchd       1976.0             2         2.0
# 2           1          2.0     Attchd       2001.0             2         2.0
# 3           1          3.0     Detchd       1998.0             1         3.0
# 4           1          2.0     Attchd       2000.0             2         3.0
#
#    GarageArea  GarageQual  GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  \
# 0       548.0           2           2          Y           0           61
# 1       460.0           2           2          Y         298            0
# 2       608.0           2           2          Y           0           42
# 3       642.0           2           2          Y           0           35
# 4       836.0           2           2          Y         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC Fence MiscFeature  \
# 0              0          0            0         0      -1   NaN         NaN
# 1              0          0            0         0      -1   NaN         NaN
# 2              0          0            0         0      -1   NaN         NaN
# 3            272          0            0         0      -1   NaN         NaN
# 4              0          0            0         0      -1   NaN         NaN
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  LotIrregularity  \
# 0        0       2    2008       WD        Normal   208500.0                0
# 1        0       5    2007       WD        Normal   181500.0                0
# 2        0       9    2008       WD        Normal   223500.0                1
# 3        0       2    2006       WD       Abnorml   140000.0                1
# 4        0      12    2008       WD        Normal   250000.0                1
#
#    BsmtExposureExist  BsmtExist  GarageExist  PoolExist  FenceExist
# 0                  0          1            1          0           0
# 1                  0          1            1          0           0
# 2                  0          1            1          0           0
# 3                  0          1            1          0           0
# 4                  0          1            1          0           0

# %% [markdown]
# ### special cases

# %% [markdown]
# **LotFrontage** : NaN becomes 0 as a numerical value
#
# The variable LotFrontage represent the linear feet of street connected to property

# %%
df.LotFrontage.isnull().sum()
# Out:
# 486

# %%
df.LotFrontage = df.LotFrontage.fillna(0)
df.LotFrontage.isnull().sum()
# Out:
# 0

# %% [markdown]
# **MasVnrType** : NaN becomes 'NA' as a category

# %%
df.MasVnrType.value_counts()
# Out:
# MasVnrType
# BrkFace    879
# Stone      249
# BrkCmn      25
# Name: count, dtype: int64

# %%
df.MasVnrType.isnull().sum()
# Out:
# 1766

# %%
df.MasVnrType = df.MasVnrType.fillna('NA')
df.MasVnrType.isnull().sum()
# Out:
# 0

# %%
df.MasVnrType.value_counts()
# Out:
# MasVnrType
# NA         1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: count, dtype: int64

# %% [markdown]
# **Electric** : column number reduction

# %%
df.Electrical = df.Electrical.fillna('NA')
df.Electrical = df.Electrical.apply(lambda a: 'Other' if a in ['FuseP', 'Mix', 'NA'] else a)
df.Electrical.value_counts()
# Out:
# Electrical
# SBrkr    2671
# FuseA     188
# FuseF      50
# Other      10
# Name: count, dtype: int64

# %% [markdown]
# **MasVnrArea** : null becomes 0 square feets

# %%
df.MasVnrArea = df.MasVnrArea.fillna(0)

# %% [markdown]
# **MiscFeature** : replace NaN by the category 'NA' (as no other feature is added)

# %%
df.MiscFeature = df.MiscFeature.fillna('NA')

# %% [markdown]
# ## Data Preparation
#
# We
# - drop all remaining missing values so that our predictive models can train on the dataset
# - create different all the different versions of the dataset to be able to play with them when we run predictive models
# - Not very legal but thee will be leakage of final_test categories to train features (when applying get_dummies to train+test data at once)

# %% [markdown]
# We drop *GarageYrBlt* (garage year built) because :
#
# 1) it is very correlated to another variable named *YearBuilt*, witch is more relevant
#
# 2) it has too many missing values (when there is no garage), and missing values and hard to deal with in numerical features because they can not be created as a seperate class with one-hot encoding. Replacing missing values with an outlier like 0 could work but some models could have a bias interpreting 0 as a year (even though we had to use this method in previous data cleaning for important numerical features with missing values)

# %%
df = df.drop(['Id', 'GarageYrBlt'], axis=1)

# %%
df.isnull().sum()[df.isnull().sum()!=0]
# Out:
# MSZoning           4
# Utilities          2
# Exterior1st        1
# Exterior2nd        1
# BsmtFinType1      79
# BsmtFinSF1         1
# BsmtFinType2      80
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# BsmtFullBath       2
# BsmtHalfBath       2
# KitchenQual        1
# Functional         2
# GarageType       157
# GarageCars         1
# GarageArea         1
# Fence           2348
# SaleType           1
# SalePrice       1459
# dtype: int64

# %% [markdown]
# *BsmtFinType1* and *BsmtFinType2* have missing values that correspond to the category 0 in the feature *BsmtExist*. So there is no need to create a new binary feature for missing values during one-hot encoding as we already have it (*BsmtExist*)
#
# The same for *GarageType* as we already have the *GarageExist* feature, and fence as we have *FenceExist* feature

# %%
len(df)
# Out:
# 2919

# %%
# df.get_dummies
# split df : [X, y] + [X_final_test]
#  [X, y] to X_train, X_test, y_train, y_test

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    LotFrontage  LotArea  Street  LandSlope  OverallQual  OverallCond  \
# 0         65.0     8450       0          1            7            5
# 1         80.0     9600       0          1            6            8
# 2         68.0    11250       0          1            7            5
# 3         60.0     9550       0          1            7            5
# 4         84.0    14260       0          1            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ExterCond  BsmtQual  \
# 0       2003          2003       196.0          3          2       3.0
# 1       1976          1976         0.0          2          2       3.0
# 2       2001          2002       162.0          3          2       3.0
# 3       1915          1970         0.0          2          2       2.0
# 4       2000          2000       350.0          3          2       3.0
#
#    BsmtCond  BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0       2.0           0.0       706.0         0.0      150.0        856.0
# 1       2.0           3.0       978.0         0.0      284.0       1262.0
# 2       2.0           1.0       486.0         0.0      434.0        920.0
# 3       3.0           0.0       216.0         0.0      540.0        756.0
# 4       2.0           2.0       655.0         0.0      490.0       1145.0
#
#    HeatingQC  CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          4           1       856       854             0       1710
# 1          4           1      1262         0             0       1262
# 2          4           1       920       866             0       1786
# 3          3           1       961       756             0       1717
# 4          4           1      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         2         1             3             1
# 1           0.0           1.0         2         0             3             1
# 2           1.0           0.0         2         1             3             1
# 3           1.0           0.0         1         0             3             1
# 4           1.0           0.0         2         1             4             1
#
#    KitchenQual  TotRmsAbvGrd  Fireplaces  FireplaceQu  GarageFinish  \
# 0          3.0             8           0         -1.0             2
# 1          2.0             6           1          2.0             2
# 2          3.0             6           1          2.0             2
# 3          3.0             7           1          3.0             1
# 4          3.0             9           1          2.0             2
#
#    GarageCars  GarageArea  GarageQual  GarageCond  WoodDeckSF  OpenPorchSF  \
# 0         2.0       548.0           2           2           0           61
# 1         2.0       460.0           2           2         298            0
# 2         2.0       608.0           2           2           0           42
# 3         3.0       642.0           2           2           0           35
# 4         3.0       836.0           2           2         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  MoSold  \
# 0              0          0            0         0      -1        0       2
# 1              0          0            0         0      -1        0       5
# 2              0          0            0         0      -1        0       9
# 3            272          0            0         0      -1        0       2
# 4              0          0            0         0      -1        0      12
#
#    YrSold  SalePrice  LotIrregularity  BsmtExposureExist  BsmtExist  \
# 0    2008   208500.0                0                  0          1
# 1    2007   181500.0                0                  0          1
# 2    2008   223500.0                1                  0          1
# 3    2006   140000.0                1                  0          1
# 4    2008   250000.0                1                  0          1
#
#    GarageExist  PoolExist  FenceExist  \
# 0            1          0           0
# 1            1          0           0
# 2            1          0           0
# 3            1          0           0
# 4            1          0           0
#
#    MSSubClass_1-1/2 STORY - UNFINISHED ALL AGES  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    MSSubClass_1-1/2 STORY FINISHED ALL AGES  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    MSSubClass_1-1/2 STORY PUD - ALL AGES  MSSubClass_1-STORY 1945 & OLDER  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
#
#    MSSubClass_1-STORY 1946 & NEWER ALL STYLES  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
#
#    MSSubClass_1-STORY PUD (Planned Unit Development) - 1946 & NEWER  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    MSSubClass_1-STORY W/FINISHED ATTIC ALL AGES  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    MSSubClass_2 FAMILY CONVERSION - ALL STYLES AND AGES  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    MSSubClass_2-1/2 STORY ALL AGES  MSSubClass_2-STORY 1945 & OLDER  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                             True
# 4                            False                            False
#
#    MSSubClass_2-STORY 1946 & NEWER  MSSubClass_2-STORY PUD - 1946 & NEWER  \
# 0                             True                                  False
# 1                            False                                  False
# 2                             True                                  False
# 3                            False                                  False
# 4                             True                                  False
#
#    MSSubClass_DUPLEX - ALL STYLES AND AGES  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    MSSubClass_PUD - MULTILEVEL - INCL SPLIT LEV/FOYER  MSSubClass_SPLIT FOYER  \
# 0                                              False                    False
# 1                                              False                    False
# 2                                              False                    False
# 3                                              False                    False
# 4                                              False                    False
#
#    MSSubClass_SPLIT OR MULTI-LEVEL  MSZoning_C (all)  MSZoning_FV  \
# 0                            False             False        False
# 1                            False             False        False
# 2                            False             False        False
# 3                            False             False        False
# 4                            False             False        False
#
#    MSZoning_RH  MSZoning_RL  MSZoning_RM  Alley_Grvl  Alley_NA  Alley_Pave  \
# 0        False         True        False       False      True       False
# 1        False         True        False       False      True       False
# 2        False         True        False       False      True       False
# 3        False         True        False       False      True       False
# 4        False         True        False       False      True       False
#
#    LandContour_Bnk  LandContour_HLS  LandContour_Low  LandContour_Lvl  \
# 0            False            False            False             True
# 1            False            False            False             True
# 2            False            False            False             True
# 3            False            False            False             True
# 4            False            False            False             True
#
#    Utilities_AllPub  Utilities_NoSeWa  LotConfig_Corner  LotConfig_CulDSac  \
# 0              True             False             False              False
# 1              True             False             False              False
# 2              True             False             False              False
# 3              True             False              True              False
# 4              True             False             False              False
#
#    LotConfig_FR2  LotConfig_FR3  LotConfig_Inside  Neighborhood_Blmngtn  \
# 0          False          False              True                 False
# 1           True          False             False                 False
# 2          False          False              True                 False
# 3          False          False             False                 False
# 4           True          False             False                 False
#
#    Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Neighborhood_ClearCr  Neighborhood_CollgCr  Neighborhood_Crawfor  \
# 0                 False                  True                 False
# 1                 False                 False                 False
# 2                 False                  True                 False
# 3                 False                 False                  True
# 4                 False                 False                 False
#
#    Neighborhood_Edwards  Neighborhood_Gilbert  Neighborhood_IDOTRR  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_MeadowV  Neighborhood_Mitchel  Neighborhood_NAmes  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    Neighborhood_NPkVill  Neighborhood_NWAmes  Neighborhood_NoRidge  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                  True
#
#    Neighborhood_NridgHt  Neighborhood_OldTown  Neighborhood_SWISU  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    Neighborhood_Sawyer  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_StoneBr  Neighborhood_Timber  Neighborhood_Veenker  \
# 0                 False                False                 False
# 1                 False                False                  True
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Condition1_Artery  Condition1_Feedr  Condition1_Norm  Condition1_PosA  \
# 0              False             False             True            False
# 1              False              True            False            False
# 2              False             False             True            False
# 3              False             False             True            False
# 4              False             False             True            False
#
#    Condition1_PosN  Condition1_RRAe  Condition1_RRAn  Condition1_RRNe  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition1_RRNn  Condition2_Artery  Condition2_Feedr  Condition2_Norm  \
# 0            False              False             False             True
# 1            False              False             False             True
# 2            False              False             False             True
# 3            False              False             False             True
# 4            False              False             False             True
#
#    Condition2_PosA  Condition2_PosN  Condition2_RRAe  Condition2_RRAn  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition2_RRNn  BldgType_1Fam  BldgType_2fmCon  BldgType_Duplex  \
# 0            False           True            False            False
# 1            False           True            False            False
# 2            False           True            False            False
# 3            False           True            False            False
# 4            False           True            False            False
#
#    BldgType_Twnhs  BldgType_TwnhsE  HouseStyle_1.5Fin  HouseStyle_1.5Unf  \
# 0           False            False              False              False
# 1           False            False              False              False
# 2           False            False              False              False
# 3           False            False              False              False
# 4           False            False              False              False
#
#    HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  HouseStyle_2Story  \
# 0              False              False              False               True
# 1               True              False              False              False
# 2              False              False              False               True
# 3              False              False              False               True
# 4              False              False              False               True
#
#    HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Flat  RoofStyle_Gable  \
# 0              False            False           False             True
# 1              False            False           False             True
# 2              False            False           False             True
# 3              False            False           False             True
# 4              False            False           False             True
#
#    RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# 0              False          False              False           False
# 1              False          False              False           False
# 2              False          False              False           False
# 3              False          False              False           False
# 4              False          False              False           False
#
#    RoofMatl_ClyTile  RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  \
# 0             False              True             False           False
# 1             False              True             False           False
# 2             False              True             False           False
# 3             False              True             False           False
# 4             False              True             False           False
#
#    RoofMatl_Roll  RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  \
# 0          False             False             False             False
# 1          False             False             False             False
# 2          False             False             False             False
# 3          False             False             False             False
# 4          False             False             False             False
#
#    Exterior1st_AsbShng  Exterior1st_AsphShn  Exterior1st_BrkComm  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_BrkFace  Exterior1st_CBlock  Exterior1st_CemntBd  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    Exterior1st_HdBoard  Exterior1st_ImStucc  Exterior1st_MetalSd  \
# 0                False                False                False
# 1                False                False                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_Plywood  Exterior1st_Stone  Exterior1st_Stucco  \
# 0                False              False               False
# 1                False              False               False
# 2                False              False               False
# 3                False              False               False
# 4                False              False               False
#
#    Exterior1st_VinylSd  Exterior1st_Wd Sdng  Exterior1st_WdShing  \
# 0                 True                False                False
# 1                False                False                False
# 2                 True                False                False
# 3                False                 True                False
# 4                 True                False                False
#
#    Exterior2nd_AsbShng  Exterior2nd_AsphShn  Exterior2nd_Brk Cmn  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_BrkFace  Exterior2nd_CBlock  Exterior2nd_CmentBd  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    Exterior2nd_HdBoard  Exterior2nd_ImStucc  Exterior2nd_MetalSd  \
# 0                False                False                False
# 1                False                False                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_Other  Exterior2nd_Plywood  Exterior2nd_Stone  \
# 0              False                False              False
# 1              False                False              False
# 2              False                False              False
# 3              False                False              False
# 4              False                False              False
#
#    Exterior2nd_Stucco  Exterior2nd_VinylSd  Exterior2nd_Wd Sdng  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                False
# 4               False                 True                False
#
#    Exterior2nd_Wd Shng  MasVnrType_BrkCmn  MasVnrType_BrkFace  MasVnrType_NA  \
# 0                False              False                True          False
# 1                False              False               False           True
# 2                False              False                True          False
# 3                 True              False               False           True
# 4                False              False                True          False
#
#    MasVnrType_Stone  Foundation_BrkTil  Foundation_CBlock  Foundation_PConc  \
# 0             False              False              False              True
# 1             False              False               True             False
# 2             False              False              False              True
# 3             False               True              False             False
# 4             False              False              False              True
#
#    Foundation_Slab  Foundation_Stone  Foundation_Wood  BsmtFinType1_ALQ  \
# 0            False             False            False             False
# 1            False             False            False              True
# 2            False             False            False             False
# 3            False             False            False              True
# 4            False             False            False             False
#
#    BsmtFinType1_BLQ  BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  \
# 0             False              True             False             False
# 1             False             False             False             False
# 2             False              True             False             False
# 3             False             False             False             False
# 4             False              True             False             False
#
#    BsmtFinType1_Unf  BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    BsmtFinType2_LwQ  BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_Floor  \
# 0             False             False              True          False
# 1             False             False              True          False
# 2             False             False              True          False
# 3             False             False              True          False
# 4             False             False              True          False
#
#    Heating_GasA  Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  \
# 0          True         False         False         False         False
# 1          True         False         False         False         False
# 2          True         False         False         False         False
# 3          True         False         False         False         False
# 4          True         False         False         False         False
#
#    Electrical_FuseA  Electrical_FuseF  Electrical_Other  Electrical_SBrkr  \
# 0             False             False             False              True
# 1             False             False             False              True
# 2             False             False             False              True
# 3             False             False             False              True
# 4             False             False             False              True
#
#    Functional_Maj1  Functional_Maj2  Functional_Min1  Functional_Min2  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Functional_Mod  Functional_Sev  Functional_Typ  GarageType_2Types  \
# 0           False           False            True              False
# 1           False           False            True              False
# 2           False           False            True              False
# 3           False           False            True              False
# 4           False           False            True              False
#
#    GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0               True               False               False
# 1               True               False               False
# 2               True               False               False
# 3              False               False               False
# 4               True               False               False
#
#    GarageType_CarPort  GarageType_Detchd  PavedDrive_N  PavedDrive_P  \
# 0               False              False         False         False
# 1               False              False         False         False
# 2               False              False         False         False
# 3               False               True         False         False
# 4               False              False         False         False
#
#    PavedDrive_Y  Fence_GdPrv  Fence_GdWo  Fence_MnPrv  Fence_MnWw  \
# 0          True        False       False        False       False
# 1          True        False       False        False       False
# 2          True        False       False        False       False
# 3          True        False       False        False       False
# 4          True        False       False        False       False
#
#    MiscFeature_Gar2  MiscFeature_NA  MiscFeature_Othr  MiscFeature_Shed  \
# 0             False            True             False             False
# 1             False            True             False             False
# 2             False            True             False             False
# 3             False            True             False             False
# 4             False            True             False             False
#
#    MiscFeature_TenC  SaleType_COD  SaleType_CWD  SaleType_Con  SaleType_ConLD  \
# 0             False         False         False         False           False
# 1             False         False         False         False           False
# 2             False         False         False         False           False
# 3             False         False         False         False           False
# 4             False         False         False         False           False
#
#    SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0           False           False         False         False         True
# 1           False           False         False         False         True
# 2           False           False         False         False         True
# 3           False           False         False         False         True
# 4           False           False         False         False         True
#
#    SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0                  False                  False                 False
# 1                  False                  False                 False
# 2                  False                  False                 False
# 3                   True                  False                 False
# 4                  False                  False                 False
#
#    SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# 0                 False                  True                  False
# 1                 False                  True                  False
# 2                 False                  True                  False
# 3                 False                 False                  False
# 4                 False                  True                  False

# %%
Xy, X_final_test = df[df['SalePrice'].isnull() == False], df[df['SalePrice'].isnull()].drop('SalePrice', axis=1)

# %%
X = Xy.drop('SalePrice', axis=1)
y = Xy['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
train = X_train.copy()
train['y'] = y_train

# %%
X.head()
# Out:
#    LotFrontage  LotArea  Street  LandSlope  OverallQual  OverallCond  \
# 0         65.0     8450       0          1            7            5
# 1         80.0     9600       0          1            6            8
# 2         68.0    11250       0          1            7            5
# 3         60.0     9550       0          1            7            5
# 4         84.0    14260       0          1            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ExterCond  BsmtQual  \
# 0       2003          2003       196.0          3          2       3.0
# 1       1976          1976         0.0          2          2       3.0
# 2       2001          2002       162.0          3          2       3.0
# 3       1915          1970         0.0          2          2       2.0
# 4       2000          2000       350.0          3          2       3.0
#
#    BsmtCond  BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0       2.0           0.0       706.0         0.0      150.0        856.0
# 1       2.0           3.0       978.0         0.0      284.0       1262.0
# 2       2.0           1.0       486.0         0.0      434.0        920.0
# 3       3.0           0.0       216.0         0.0      540.0        756.0
# 4       2.0           2.0       655.0         0.0      490.0       1145.0
#
#    HeatingQC  CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          4           1       856       854             0       1710
# 1          4           1      1262         0             0       1262
# 2          4           1       920       866             0       1786
# 3          3           1       961       756             0       1717
# 4          4           1      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0           1.0           0.0         2         1             3             1
# 1           0.0           1.0         2         0             3             1
# 2           1.0           0.0         2         1             3             1
# 3           1.0           0.0         1         0             3             1
# 4           1.0           0.0         2         1             4             1
#
#    KitchenQual  TotRmsAbvGrd  Fireplaces  FireplaceQu  GarageFinish  \
# 0          3.0             8           0         -1.0             2
# 1          2.0             6           1          2.0             2
# 2          3.0             6           1          2.0             2
# 3          3.0             7           1          3.0             1
# 4          3.0             9           1          2.0             2
#
#    GarageCars  GarageArea  GarageQual  GarageCond  WoodDeckSF  OpenPorchSF  \
# 0         2.0       548.0           2           2           0           61
# 1         2.0       460.0           2           2         298            0
# 2         2.0       608.0           2           2           0           42
# 3         3.0       642.0           2           2           0           35
# 4         3.0       836.0           2           2         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  MiscVal  MoSold  \
# 0              0          0            0         0      -1        0       2
# 1              0          0            0         0      -1        0       5
# 2              0          0            0         0      -1        0       9
# 3            272          0            0         0      -1        0       2
# 4              0          0            0         0      -1        0      12
#
#    YrSold  LotIrregularity  BsmtExposureExist  BsmtExist  GarageExist  \
# 0    2008                0                  0          1            1
# 1    2007                0                  0          1            1
# 2    2008                1                  0          1            1
# 3    2006                1                  0          1            1
# 4    2008                1                  0          1            1
#
#    PoolExist  FenceExist  MSSubClass_1-1/2 STORY - UNFINISHED ALL AGES  \
# 0          0           0                                         False
# 1          0           0                                         False
# 2          0           0                                         False
# 3          0           0                                         False
# 4          0           0                                         False
#
#    MSSubClass_1-1/2 STORY FINISHED ALL AGES  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    MSSubClass_1-1/2 STORY PUD - ALL AGES  MSSubClass_1-STORY 1945 & OLDER  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
#
#    MSSubClass_1-STORY 1946 & NEWER ALL STYLES  \
# 0                                       False
# 1                                        True
# 2                                       False
# 3                                       False
# 4                                       False
#
#    MSSubClass_1-STORY PUD (Planned Unit Development) - 1946 & NEWER  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    MSSubClass_1-STORY W/FINISHED ATTIC ALL AGES  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    MSSubClass_2 FAMILY CONVERSION - ALL STYLES AND AGES  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    MSSubClass_2-1/2 STORY ALL AGES  MSSubClass_2-STORY 1945 & OLDER  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                             True
# 4                            False                            False
#
#    MSSubClass_2-STORY 1946 & NEWER  MSSubClass_2-STORY PUD - 1946 & NEWER  \
# 0                             True                                  False
# 1                            False                                  False
# 2                             True                                  False
# 3                            False                                  False
# 4                             True                                  False
#
#    MSSubClass_DUPLEX - ALL STYLES AND AGES  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    MSSubClass_PUD - MULTILEVEL - INCL SPLIT LEV/FOYER  MSSubClass_SPLIT FOYER  \
# 0                                              False                    False
# 1                                              False                    False
# 2                                              False                    False
# 3                                              False                    False
# 4                                              False                    False
#
#    MSSubClass_SPLIT OR MULTI-LEVEL  MSZoning_C (all)  MSZoning_FV  \
# 0                            False             False        False
# 1                            False             False        False
# 2                            False             False        False
# 3                            False             False        False
# 4                            False             False        False
#
#    MSZoning_RH  MSZoning_RL  MSZoning_RM  Alley_Grvl  Alley_NA  Alley_Pave  \
# 0        False         True        False       False      True       False
# 1        False         True        False       False      True       False
# 2        False         True        False       False      True       False
# 3        False         True        False       False      True       False
# 4        False         True        False       False      True       False
#
#    LandContour_Bnk  LandContour_HLS  LandContour_Low  LandContour_Lvl  \
# 0            False            False            False             True
# 1            False            False            False             True
# 2            False            False            False             True
# 3            False            False            False             True
# 4            False            False            False             True
#
#    Utilities_AllPub  Utilities_NoSeWa  LotConfig_Corner  LotConfig_CulDSac  \
# 0              True             False             False              False
# 1              True             False             False              False
# 2              True             False             False              False
# 3              True             False              True              False
# 4              True             False             False              False
#
#    LotConfig_FR2  LotConfig_FR3  LotConfig_Inside  Neighborhood_Blmngtn  \
# 0          False          False              True                 False
# 1           True          False             False                 False
# 2          False          False              True                 False
# 3          False          False             False                 False
# 4           True          False             False                 False
#
#    Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Neighborhood_ClearCr  Neighborhood_CollgCr  Neighborhood_Crawfor  \
# 0                 False                  True                 False
# 1                 False                 False                 False
# 2                 False                  True                 False
# 3                 False                 False                  True
# 4                 False                 False                 False
#
#    Neighborhood_Edwards  Neighborhood_Gilbert  Neighborhood_IDOTRR  \
# 0                 False                 False                False
# 1                 False                 False                False
# 2                 False                 False                False
# 3                 False                 False                False
# 4                 False                 False                False
#
#    Neighborhood_MeadowV  Neighborhood_Mitchel  Neighborhood_NAmes  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    Neighborhood_NPkVill  Neighborhood_NWAmes  Neighborhood_NoRidge  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                  True
#
#    Neighborhood_NridgHt  Neighborhood_OldTown  Neighborhood_SWISU  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    Neighborhood_Sawyer  Neighborhood_SawyerW  Neighborhood_Somerst  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_StoneBr  Neighborhood_Timber  Neighborhood_Veenker  \
# 0                 False                False                 False
# 1                 False                False                  True
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Condition1_Artery  Condition1_Feedr  Condition1_Norm  Condition1_PosA  \
# 0              False             False             True            False
# 1              False              True            False            False
# 2              False             False             True            False
# 3              False             False             True            False
# 4              False             False             True            False
#
#    Condition1_PosN  Condition1_RRAe  Condition1_RRAn  Condition1_RRNe  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition1_RRNn  Condition2_Artery  Condition2_Feedr  Condition2_Norm  \
# 0            False              False             False             True
# 1            False              False             False             True
# 2            False              False             False             True
# 3            False              False             False             True
# 4            False              False             False             True
#
#    Condition2_PosA  Condition2_PosN  Condition2_RRAe  Condition2_RRAn  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Condition2_RRNn  BldgType_1Fam  BldgType_2fmCon  BldgType_Duplex  \
# 0            False           True            False            False
# 1            False           True            False            False
# 2            False           True            False            False
# 3            False           True            False            False
# 4            False           True            False            False
#
#    BldgType_Twnhs  BldgType_TwnhsE  HouseStyle_1.5Fin  HouseStyle_1.5Unf  \
# 0           False            False              False              False
# 1           False            False              False              False
# 2           False            False              False              False
# 3           False            False              False              False
# 4           False            False              False              False
#
#    HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  HouseStyle_2Story  \
# 0              False              False              False               True
# 1               True              False              False              False
# 2              False              False              False               True
# 3              False              False              False               True
# 4              False              False              False               True
#
#    HouseStyle_SFoyer  HouseStyle_SLvl  RoofStyle_Flat  RoofStyle_Gable  \
# 0              False            False           False             True
# 1              False            False           False             True
# 2              False            False           False             True
# 3              False            False           False             True
# 4              False            False           False             True
#
#    RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# 0              False          False              False           False
# 1              False          False              False           False
# 2              False          False              False           False
# 3              False          False              False           False
# 4              False          False              False           False
#
#    RoofMatl_ClyTile  RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  \
# 0             False              True             False           False
# 1             False              True             False           False
# 2             False              True             False           False
# 3             False              True             False           False
# 4             False              True             False           False
#
#    RoofMatl_Roll  RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  \
# 0          False             False             False             False
# 1          False             False             False             False
# 2          False             False             False             False
# 3          False             False             False             False
# 4          False             False             False             False
#
#    Exterior1st_AsbShng  Exterior1st_AsphShn  Exterior1st_BrkComm  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_BrkFace  Exterior1st_CBlock  Exterior1st_CemntBd  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    Exterior1st_HdBoard  Exterior1st_ImStucc  Exterior1st_MetalSd  \
# 0                False                False                False
# 1                False                False                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior1st_Plywood  Exterior1st_Stone  Exterior1st_Stucco  \
# 0                False              False               False
# 1                False              False               False
# 2                False              False               False
# 3                False              False               False
# 4                False              False               False
#
#    Exterior1st_VinylSd  Exterior1st_Wd Sdng  Exterior1st_WdShing  \
# 0                 True                False                False
# 1                False                False                False
# 2                 True                False                False
# 3                False                 True                False
# 4                 True                False                False
#
#    Exterior2nd_AsbShng  Exterior2nd_AsphShn  Exterior2nd_Brk Cmn  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_BrkFace  Exterior2nd_CBlock  Exterior2nd_CmentBd  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    Exterior2nd_HdBoard  Exterior2nd_ImStucc  Exterior2nd_MetalSd  \
# 0                False                False                False
# 1                False                False                 True
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    Exterior2nd_Other  Exterior2nd_Plywood  Exterior2nd_Stone  \
# 0              False                False              False
# 1              False                False              False
# 2              False                False              False
# 3              False                False              False
# 4              False                False              False
#
#    Exterior2nd_Stucco  Exterior2nd_VinylSd  Exterior2nd_Wd Sdng  \
# 0               False                 True                False
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                False
# 4               False                 True                False
#
#    Exterior2nd_Wd Shng  MasVnrType_BrkCmn  MasVnrType_BrkFace  MasVnrType_NA  \
# 0                False              False                True          False
# 1                False              False               False           True
# 2                False              False                True          False
# 3                 True              False               False           True
# 4                False              False                True          False
#
#    MasVnrType_Stone  Foundation_BrkTil  Foundation_CBlock  Foundation_PConc  \
# 0             False              False              False              True
# 1             False              False               True             False
# 2             False              False              False              True
# 3             False               True              False             False
# 4             False              False              False              True
#
#    Foundation_Slab  Foundation_Stone  Foundation_Wood  BsmtFinType1_ALQ  \
# 0            False             False            False             False
# 1            False             False            False              True
# 2            False             False            False             False
# 3            False             False            False              True
# 4            False             False            False             False
#
#    BsmtFinType1_BLQ  BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_Rec  \
# 0             False              True             False             False
# 1             False             False             False             False
# 2             False              True             False             False
# 3             False             False             False             False
# 4             False              True             False             False
#
#    BsmtFinType1_Unf  BsmtFinType2_ALQ  BsmtFinType2_BLQ  BsmtFinType2_GLQ  \
# 0             False             False             False             False
# 1             False             False             False             False
# 2             False             False             False             False
# 3             False             False             False             False
# 4             False             False             False             False
#
#    BsmtFinType2_LwQ  BsmtFinType2_Rec  BsmtFinType2_Unf  Heating_Floor  \
# 0             False             False              True          False
# 1             False             False              True          False
# 2             False             False              True          False
# 3             False             False              True          False
# 4             False             False              True          False
#
#    Heating_GasA  Heating_GasW  Heating_Grav  Heating_OthW  Heating_Wall  \
# 0          True         False         False         False         False
# 1          True         False         False         False         False
# 2          True         False         False         False         False
# 3          True         False         False         False         False
# 4          True         False         False         False         False
#
#    Electrical_FuseA  Electrical_FuseF  Electrical_Other  Electrical_SBrkr  \
# 0             False             False             False              True
# 1             False             False             False              True
# 2             False             False             False              True
# 3             False             False             False              True
# 4             False             False             False              True
#
#    Functional_Maj1  Functional_Maj2  Functional_Min1  Functional_Min2  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Functional_Mod  Functional_Sev  Functional_Typ  GarageType_2Types  \
# 0           False           False            True              False
# 1           False           False            True              False
# 2           False           False            True              False
# 3           False           False            True              False
# 4           False           False            True              False
#
#    GarageType_Attchd  GarageType_Basment  GarageType_BuiltIn  \
# 0               True               False               False
# 1               True               False               False
# 2               True               False               False
# 3              False               False               False
# 4               True               False               False
#
#    GarageType_CarPort  GarageType_Detchd  PavedDrive_N  PavedDrive_P  \
# 0               False              False         False         False
# 1               False              False         False         False
# 2               False              False         False         False
# 3               False               True         False         False
# 4               False              False         False         False
#
#    PavedDrive_Y  Fence_GdPrv  Fence_GdWo  Fence_MnPrv  Fence_MnWw  \
# 0          True        False       False        False       False
# 1          True        False       False        False       False
# 2          True        False       False        False       False
# 3          True        False       False        False       False
# 4          True        False       False        False       False
#
#    MiscFeature_Gar2  MiscFeature_NA  MiscFeature_Othr  MiscFeature_Shed  \
# 0             False            True             False             False
# 1             False            True             False             False
# 2             False            True             False             False
# 3             False            True             False             False
# 4             False            True             False             False
#
#    MiscFeature_TenC  SaleType_COD  SaleType_CWD  SaleType_Con  SaleType_ConLD  \
# 0             False         False         False         False           False
# 1             False         False         False         False           False
# 2             False         False         False         False           False
# 3             False         False         False         False           False
# 4             False         False         False         False           False
#
#    SaleType_ConLI  SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0           False           False         False         False         True
# 1           False           False         False         False         True
# 2           False           False         False         False         True
# 3           False           False         False         False         True
# 4           False           False         False         False         True
#
#    SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0                  False                  False                 False
# 1                  False                  False                 False
# 2                  False                  False                 False
# 3                   True                  False                 False
# 4                  False                  False                 False
#
#    SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# 0                 False                  True                  False
# 1                 False                  True                  False
# 2                 False                  True                  False
# 3                 False                 False                  False
# 4                 False                  True                  False

# %%
scaler = StandardScaler()
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

# scaled
scaled_X_train = pd.DataFrame(scaler.fit_transform(X_train), columns = X_train.columns, index = X_train.index)
scaled_X_test = pd.DataFrame(scaler.transform(X_test), columns = X_test.columns, index = X_test.index)

scaled_train = scaled_X_train.copy()
scaled_train['y'] = y_train.sort_index()


# numer
numer_X_train = X_train.select_dtypes(include=numerics)
numer_X_train = numer_X_train[numer_X_train.columns[:-5].tolist()]

numer_X_test = X_test.select_dtypes(include=numerics)
numer_X_test = numer_X_test[numer_X_test.columns[:-5].tolist()]

numer_train = numer_X_train.copy()
numer_train['y']= y_train.sort_index()


# numer + scaled
numer_scaled_X_train = pd.DataFrame(scaler.fit_transform(numer_X_train), columns = numer_X_train.columns, index = numer_X_train.index)
numer_scaled_X_test = pd.DataFrame(scaler.transform(numer_X_test), columns = numer_X_test.columns, index = numer_X_test.index)

numer_scaled_train = numer_scaled_X_train.copy()
numer_scaled_train['y'] = y_train.sort_index()

# %% [markdown]
# # **Dimentionnality reduction**
# - RF feature selection
# - PCA
# - CCA

# %% [markdown]
# ## Feature selection with Random Forest
#
# Creation of a new version of the feature set that involves only the most relevant features according to the random forest regressor model (dimentionnality reduction)

# %% [markdown]
# Because we noticed (further away in this notebook), that for every model, the results are either the same or improve when the dataset is only numerical (no dummy variables), we want to get the feature importances to verify our hypotesis that the categorical features don't have an impact on the price, and have a look on the most relevant features for price prediction. We will use the Random forest model as it is quite reliable on this field. Remember that the feature importances will be given in percentages, so they sum up to 100.

# %%
model = RandomForestRegressor()
model.fit(scaled_X_train, y_train)
preds = model.predict(scaled_X_test)

# %%
mean_absolute_percentage_error(y_test, preds)
# Out:
# 0.09209690772962417

# %%
root_mean_squared_error(y_test, preds)
# Out:
# 30406.520999290948

# %%
fi = pd.DataFrame([model.feature_names_in_, model.feature_importances_]).T.sort_values(1, ascending=False)
fi[1]=fi[1]*100
fi.head()
# Out:
#               0          1
# 4   OverallQual  56.407533
# 23    GrLivArea  10.975478
# 17  TotalBsmtSF   4.352278
# 20     1stFlrSF   3.133925
# 14   BsmtFinSF1   3.105786

# %%
plt.figure(figsize=(13, 4))
sns.barplot(x=fi[0].iloc[:25], y=fi[1].iloc[:25])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Our hypotesis is verified as no dummy variable is present in the 25 most important features, that gather combined 95 percent of the importance for price prediction. We will later perform the ANOVA test in order to verify if there are still categorical variables that are linked to price
#
# --> let's create a new dataset only with these features

# %%
fi[0].head(25).values.tolist()
# Out:
# ['OverallQual',
#  'GrLivArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'BsmtFinSF1',
#  '2ndFlrSF',
#  'GarageArea',
#  'LotArea',
#  'GarageCars',
#  'YearBuilt',
#  'FullBath',
#  'LotFrontage',
#  'BsmtQual',
#  'YearRemodAdd',
#  'TotRmsAbvGrd',
#  'OpenPorchSF',
#  'KitchenQual',
#  'BsmtUnfSF',
#  'WoodDeckSF',
#  'GarageFinish',
#  'OverallCond',
#  'CentralAir',
#  'MasVnrArea',
#  'FireplaceQu',
#  'MoSold']

# %%
scaled_topfi_X_train = scaled_X_train[fi[0].head(25).values.tolist()]
print(len(scaled_topfi_X_train))
scaled_topfi_X_test = scaled_X_test[fi[0].head(25).values.tolist()]
print(len(scaled_topfi_X_train))
scaled_topfi_train = scaled_X_train.copy()
print(len(scaled_topfi_X_train))
scaled_topfi_train['y']=y_train
print(len(scaled_topfi_X_train))
# Out:
# 1314
# 1314
# 1314
# 1314

# %%
len(scaled_X_train)
# Out:
# 1314

# %%
len(y_train)
# Out:
# 1314

# %%
print(len(scaled_topfi_X_train))
# Out:
# 1314

# %% [markdown]
# ## PCA
#
# As we have around 50 numerical variables, we will be the create a new version of our feature set, but with less variables (dimentionality reduction). We will not select features from feature set, but rather create new features from our feature set. Each one of these new created features will be a linear combinaison of all our initial features, that gather as much information as they can (without being correlated). These are called components.
#
# - The purpose  is here is **exploratory** : understand the meaning of the principal components to know the underlying information of our data
#
# *We will then create a new version of our feature set (version where features will be the pca components). Note that we will accidently discover two outliers in out dataset that may bring down the performance of our future models. So they will be dropped*

# %% [markdown]
# The graph below represents the amount of information gathered from the original features according to the number of components that we keep

# %%
pca = PCA(n_components=len(numer_X_train.columns))

numer_scaled_pc_X_train = pd.DataFrame(pca.fit_transform(numer_scaled_X_train))


components_variance = pca.explained_variance_ratio_*100
components_variance_accumulated = np.array([components_variance[i] + np.sum(components_variance[:i]) for i in range(len(components_variance))])
pd.Series(components_variance_accumulated).plot()
plt.xlabel('number of components (top ones)')
plt.ylabel('accumulated variance')
plt.show()

# %% [markdown]
# We want
#
# --> as few components as possible
#
# --> the highest possible accumulated variance (can be understood as the information gathered by the components)

# %% [markdown]
# We should note that the **component 1** gather as much variance as possible
#
# **component 2** gather as much variance as possible witch has not been gathered by component 1
#
# **component 3** gather as much variance as possible witch has not been gathered by component 1 and component 2
#
# **etc**
#
# - So the variance gathered decreases as we go through components from the top to the end one, but the accumulated variance increase (plot)

# %%
len(components_variance_accumulated[components_variance_accumulated<80])
# Out:
# 21

# %% [markdown]
# **If we want to keep 80 percent of the initial variance, we would need to keep 21 components**
# This seems to be a good trade-off

# %%
len(components_variance_accumulated[components_variance_accumulated<80])
# Out:
# 21

# %% [markdown]
# (code executed in the data cleaning section)

# %%
pca = PCA(n_components=21)

numer_scaled_pc_X_train = pd.DataFrame(pca.fit_transform(numer_scaled_X_train), index = numer_scaled_X_train.index)
numer_scaled_pc_X_test = pd.DataFrame(pca.fit_transform(numer_scaled_X_test), index = numer_scaled_X_test.index)
numer_scaled_pc_train = numer_scaled_pc_X_train.copy()
numer_scaled_pc_train['y']=y_train.sort_index()

# %% [markdown]
# let's check the components that are mostly correlated to *y* (in terms of absolute value correlations)

# %%
abs(numer_scaled_pc_train.corr()['y']).sort_values(ascending=False)*100
# Out:
# y     100.000000
# 0      86.573694
# 2       9.250682
# 1       8.468621
# 3       8.240268
# 4       7.458708
# 17      5.871146
# 5       5.091473
# 8       5.042899
# 11      4.963648
# 9       4.774039
# 7       4.295898
# 10      3.053429
# 20      2.360952
# 14      1.057502
# 18      0.992418
# 19      0.841698
# 13      0.731322
# 6       0.640812
# 16      0.499943
# 15      0.485188
# 12      0.040255
# Name: y, dtype: float64

# %% [markdown]
# *We can notice a very high correlation between component 1 and the output (86 percent), but the correlations don't necessarly go down with the component rank. As we can see, some low rank components (like component 17) are more correlated to y than high rank components (like component 7). This is because the information gathered with the pca components is not necessarly the one correlated to y. Therefore, for predictions purposes, we will not use pca components*

# %% [markdown]
# **As we remarked a very high correlation between component 1 and y, let's plot these 2 variables into a graph**

# %%
sns.scatterplot(x=numer_scaled_pc_train[0], y=numer_scaled_pc_train['y'])
plt.xlabel('component 1')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# It looks like the relationship is polynomial, so let's see what we would get from a polynomial regression curve (degree 2 will be sufficient)

# %%
poly_converter = PolynomialFeatures(degree = 2, include_bias=False)
numer_scaled_pc1_poly_X_train = pd.DataFrame(poly_converter.fit_transform(numer_scaled_pc_X_train[0].to_frame()), index = numer_scaled_pc_X_train.index)
numer_scaled_pc1_poly_X_test = pd.DataFrame(poly_converter.transform(numer_scaled_pc_X_test[0].to_frame()), index = numer_scaled_pc_X_test.index)

lr = LinearRegression()
lr.fit(numer_scaled_pc1_poly_X_train, y_train)
# Out:
# LinearRegression()

# %%
preds = lr.predict(numer_scaled_pc1_poly_X_train)

sns.scatterplot(x=numer_scaled_pc_train[0], y=numer_scaled_pc_train['y'])
sns.lineplot(x = numer_scaled_pc_train[0], y=preds, palette=['r'])
plt.show()
# Out:
# <ipython-input-286-7c203b282d21>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x = numer_scaled_pc_train[0], y=preds, palette=['r'])

# %%
preds = lr.predict(numer_scaled_pc1_poly_X_test)
mape = mean_absolute_percentage_error(y_test, preds)
rmse = root_mean_squared_error(y_test, preds)
print('mean absolute percentage error (test set) : ', mape)
print('root mean squared error (test set) : ', rmse)
# Out:
# mean absolute percentage error (test set) :  0.1154688783564347
# root mean squared error (test set) :  35242.50848591702

# %% [markdown]
# It seems that the two ouliers in bottom down are bringing down the regression curve, preventing it to go though the real trend of the data.
#
# Let's drop them to see if the curve fits better than real trend

# %%
index_outliers = numer_scaled_pc_train[(numer_scaled_pc_train[0]>10) & (numer_scaled_pc_train['y']<250000)].index
index_outliers

numer_scaled_pc_train = numer_scaled_pc_train.drop(index_outliers)
numer_scaled_pc_X_train = numer_scaled_pc_X_train.drop(index_outliers)

numer_scaled_train = numer_scaled_train.drop(index_outliers)
numer_scaled_X_train = numer_scaled_X_train.drop(index_outliers)

numer_train = numer_train.drop(index_outliers)
numer_X_train = numer_X_train.drop(index_outliers)

scaled_train = scaled_train.drop(index_outliers)
scaled_X_train = scaled_X_train.drop(index_outliers)

train = train.drop(index_outliers)
X_train = X_train.drop(index_outliers)

y_train = y_train.drop(index_outliers)

# %%
poly_converter = PolynomialFeatures(degree = 2, include_bias=False)
numer_scaled_pc1_poly_X_train = pd.DataFrame(poly_converter.fit_transform(numer_scaled_pc_X_train[0].to_frame()), index = numer_scaled_pc_X_train.index)
numer_scaled_pc1_poly_X_test = pd.DataFrame(poly_converter.transform(numer_scaled_pc_X_test[0].to_frame()), index = numer_scaled_pc_X_test.index)

lr = LinearRegression()
lr.fit(numer_scaled_pc1_poly_X_train, y_train)
# Out:
# LinearRegression()

# %%
preds = lr.predict(numer_scaled_pc1_poly_X_train)

sns.scatterplot(x=numer_scaled_pc_train[0], y=numer_scaled_pc_train['y'])
sns.lineplot(x = numer_scaled_pc_train[0], y=preds, palette=['r'])
plt.show()
# Out:
# <ipython-input-290-7c203b282d21>:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x = numer_scaled_pc_train[0], y=preds, palette=['r'])

# %% [markdown]
# The curve seems better right now

# %%
preds = lr.predict(numer_scaled_pc1_poly_X_test)
mape = mean_absolute_percentage_error(y_test, preds)
rmse = root_mean_squared_error(y_test, preds)
print('mean absolute percentage error (test set) : ', mape)
print('root mean squared error (test set) : ', rmse)
# Out:
# mean absolute percentage error (test set) :  0.11750698965179629
# root mean squared error (test set) :  27589.819380393677

# %% [markdown]
# We also got better error metrics values on test set (especially root mean squared error)

# %% [markdown]
# ## CCA (canonical correlation analysis)

# %%
numer_scaled_X_train.head()
# Out:
#      LotFrontage   LotArea    Street  LandSlope  OverallQual  OverallCond  \
# 907     0.828499  0.084557 -0.061804  -0.226985     0.650071     1.282993
# 782     0.281816  0.543774 -0.061804  -0.226985     0.650071    -0.520058
# 952     0.080406 -0.328114 -0.061804  -0.226985    -0.806355     2.184519
# 620    -0.351186 -0.227537 -0.061804  -0.226985    -2.262781    -2.323109
# 669     0.655862  0.094154 -0.061804  -0.226985    -1.534568    -0.520058
#
#      YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ExterCond  BsmtQual  \
# 907  -1.149679      0.105391   -0.583936   1.054453  -0.245608  0.585262
# 782   0.984929      0.830435   -0.583936   1.054453  -0.245608  0.585262
# 952   0.032565      0.878772   -0.583936  -0.692774   2.536542  0.585262
# 620  -1.872162     -1.683052   -0.583936  -0.692774  -0.245608 -0.564266
# 669  -1.609441     -1.683052   -0.583936  -0.692774  -0.245608 -1.713793
#
#      BsmtCond  BsmtExposure  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 907  0.111308     -0.589150   -0.489611   -0.279269   0.510827    -0.091069
# 782  0.111308     -0.589150   -0.979513   -0.279269   1.906397     0.818618
# 952  0.111308      1.299005    0.470421   -0.279269  -1.035799    -0.663070
# 620  0.111308     -0.589150   -0.889441   -0.279269   0.576209    -0.442540
# 669  0.111308     -0.589150   -0.979513   -0.279269   0.298899    -0.819279
#
#      HeatingQC  CentralAir  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 907  -0.145790    0.267914 -0.374017  1.573191     -0.115327   1.035525
# 782   0.895339    0.267914  0.693131 -0.804206     -0.115327  -0.173416
# 952  -0.145790    0.267914 -1.029922 -0.804206     -0.115327  -1.449842
# 620  -1.186918   -3.732535 -0.780053 -0.804206     -0.115327  -1.264741
# 669   0.895339    0.267914  0.042431 -0.804206     -0.115327  -0.655450
#
#      BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 907     -0.814662     -0.241125 -1.036178  1.225098      0.150991
# 782     -0.814662     -0.241125  0.776788 -0.762283      0.150991
# 952     -0.814662      3.927804 -1.036178 -0.762283     -1.081322
# 620      1.103735     -0.241125 -1.036178 -0.762283     -1.081322
# 669     -0.814662     -0.241125 -1.036178 -0.762283     -1.081322
#
#      KitchenAbvGr  KitchenQual  TotRmsAbvGrd  Fireplaces  FireplaceQu  \
# 907     -0.215886     0.744873     -0.337025    0.595745     1.194526
# 782     -0.215886     0.744873     -0.337025   -0.957447    -1.016189
# 952     -0.215886    -0.770240     -0.958135   -0.957447    -1.016189
# 620     -0.215886    -0.770240     -0.958135   -0.957447    -1.016189
# 669     -0.215886    -2.285352     -0.958135    0.595745     1.194526
#
#      GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  WoodDeckSF  \
# 907      1.307561   -1.037159   -1.391842   -1.121741    0.265876   -0.748606
# 782      0.328566    0.310840    0.631209    0.259672    0.265876   -0.748606
# 952      1.307561   -1.037159   -0.363657    0.259672    0.265876    0.766344
# 620     -2.608416   -2.385157   -2.248664   -3.884568   -3.893185   -0.748606
# 669     -0.650428   -1.037159   -1.049114    0.259672   -1.120478   -0.748606
#
#      OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea    PoolQC  \
# 907    -0.709671      -0.357887  -0.122175     5.450039 -0.072426 -0.069836
# 782    -0.220601      -0.357887  -0.122175    -0.271111 -0.072426 -0.069836
# 952    -0.709671      -0.357887  -0.122175    -0.271111 -0.072426 -0.069836
# 620    -0.709671       1.259140  -0.122175    -0.271111 -0.072426 -0.069836
# 669    -0.709671       0.725521  -0.122175    -0.271111 -0.072426 -0.069836
#
#       MiscVal    MoSold    YrSold  LotIrregularity
# 907 -0.089448 -0.128250 -1.364068         0.998271
# 782 -0.089448 -0.128250  0.884847         2.701813
# 952 -0.089448 -0.872269  0.884847        -0.705272
# 620 -0.089448  0.987779  0.135209        -0.705272
# 669 -0.089448  0.243760 -1.364068        -0.705272

# %%
from sklearn.cross_decomposition import CCA

cca = CCA(n_components=1)
cca.fit(numer_scaled_X_train, y_train)
scaled_numer_cca_X_train = pd.DataFrame(cca.transform(numer_scaled_X_train), index = numer_scaled_X_train.index)
scaled_numer_cca_X_test = pd.DataFrame(cca.transform(numer_scaled_X_test), index = numer_scaled_X_test.index)

scaled_numer_cca_train = scaled_numer_cca_X_train.copy()
scaled_numer_cca_train['y']=y_train

# %% [markdown]
# correlation between the cca component and the price is 94 percent (pca component was 86 percent)

# %%
cca.coef_[0].tolist()
# Out:
# [7563.626313923415,
#  10089.534772009503,
#  -3910.0838861404495,
#  1102.6818056337058,
#  28961.994182184502,
#  15321.827107818372,
#  17033.022349177747,
#  -2440.9998876131276,
#  7324.519719376287,
#  12973.074325786072,
#  -1961.1742868413194,
#  6677.531657400873,
#  -13342.71713742673,
#  9299.446867769293,
#  20944.35563966995,
#  1415.9342532533576,
#  1878.5353737872636,
#  24864.019584395224,
#  2264.172118816374,
#  -789.6372008303978,
#  15479.303977550644,
#  21844.46618480552,
#  -2090.2425524164714,
#  30911.08688779097,
#  -780.3839491508683,
#  -3968.155033705796,
#  -892.2124337269166,
#  1235.9713585974591,
#  -14152.12315472156,
#  -12201.885684406458,
#  11180.928571453034,
#  15240.34984310544,
#  2108.925464893803,
#  1720.451239629529,
#  -162.8406570393045,
#  2687.555651288776,
#  13510.056418715429,
#  3236.9447995038036,
#  -12104.661966261257,
#  3550.957649856864,
#  1303.4229807953443,
#  -1325.4771378061096,
#  899.8781630128493,
#  3933.932083659806,
#  -8448.010051433885,
#  15705.873602681953,
#  -189.41687171792407,
#  117.33081927189217,
#  -1006.7378746035154,
#  5318.0101188677445]

# %%
fi[0].head()
# Out:
# 4     OverallQual
# 23      GrLivArea
# 17    TotalBsmtSF
# 14     BsmtFinSF1
# 20       1stFlrSF
# Name: 0, dtype: object

# %%
pd.DataFrame([cca.coef_[0].tolist()], columns = numer_scaled_X_train.columns.tolist()).T.sort_values(by=0)
# Out:
#                             0
# BedroomAbvGr    -14152.123155
# BsmtCond        -13342.717137
# KitchenAbvGr    -12201.885684
# GarageCond      -12104.661966
# PoolArea         -8448.010051
# BsmtHalfBath     -3968.155034
# Street           -3910.083886
# YearRemodAdd     -2440.999888
# LowQualFinSF     -2090.242552
# ExterCond        -1961.174287
# EnclosedPorch    -1325.477138
# YrSold           -1006.737875
# FullBath          -892.212434
# CentralAir        -789.637201
# BsmtFullBath      -780.383949
# MiscVal           -189.416872
# GarageFinish      -162.840657
# MoSold             117.330819
# 3SsnPorch          899.878163
# LandSlope         1102.681806
# HalfBath          1235.971359
# OpenPorchSF       1303.422981
# BsmtFinSF2        1415.934253
# FireplaceQu       1720.451240
# BsmtUnfSF         1878.535374
# Fireplaces        2108.925465
# HeatingQC         2264.172119
# GarageCars        2687.555651
# GarageQual        3236.944800
# WoodDeckSF        3550.957650
# ScreenPorch       3933.932084
# LotIrregularity   5318.010119
# BsmtQual          6677.531657
# MasVnrArea        7324.519719
# LotFrontage       7563.626314
# BsmtExposure      9299.446868
# LotArea          10089.534772
# KitchenQual      11180.928571
# ExterQual        12973.074326
# GarageArea       13510.056419
# TotRmsAbvGrd     15240.349843
# OverallCond      15321.827108
# 1stFlrSF         15479.303978
# PoolQC           15705.873603
# YearBuilt        17033.022349
# BsmtFinSF1       20944.355640
# 2ndFlrSF         21844.466185
# TotalBsmtSF      24864.019584
# OverallQual      28961.994182
# GrLivArea        30911.086888

# %%
scaled_numer_cca_train.corr()['y'].loc[0]
# Out:
# 0.9400198235416347

# %%
sns.scatterplot(x = scaled_numer_cca_X_train[0], y = y_train)
plt.xlabel('our cca component')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
lr = LinearRegression()
lr.fit(scaled_numer_cca_X_train, y_train)
preds = lr.predict(scaled_numer_cca_X_test)
mape = mean_absolute_percentage_error(y_test, preds)
rmse = root_mean_squared_error(y_test, preds)

# %%
mape
# Out:
# 0.11903715937965939

# %%
rmse
# Out:
# 33971.0625693235

# %% [markdown]
# # **Prediction Models**

# %% [markdown]
# Accuracy generally improves with
# - Number of predictive features
# - Hyperparameter optimisation of a model

# %% [markdown]
# ## Step 1 : train/testing different models on different dataset versions to choose the best pipeline for the final predictions in kaggle

# %% [markdown]
# ### Model 1 : Random Forest Regressor [mape = 9.14%, rmse = 29722]
# We will create and evaluate 3 versions of Random Forest Regressor

# %% [markdown]
# #### No Hyperparameter tuning (default ones)

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
preds1_1 = model.predict(X_test)

# %% [markdown]
# mean absolute percentage error

# %%
mean_absolute_percentage_error(y_test, preds1_1)*100
# Out:
# 9.342850847270405

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds1_1)
# Out:
# 16481.33808219178

# %% [markdown]
# root mean squared error

# %%
root_mean_squared_error(y_test, preds1_1)
# Out:
# 30163.083295493914

# %% [markdown]
# #### Hyperparameter tuning through GridSearchCV

# %%
model = RandomForestRegressor()

param_grid = {
        "n_estimators"      : [50, 100, 150, 200],
        "max_features"      : ["sqrt", "log2", 1.0],
        "min_samples_split" : [2,4,8],
        "bootstrap": [True, False]
        }

cvmodel = GridSearchCV(model, param_grid, n_jobs=-1, cv=5, verbose = 5, scoring='neg_mean_squared_error')
cvmodel.fit(scaled_X_train, y_train)
preds1_2 = cvmodel.predict(scaled_X_test)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits

# %% [markdown]
# mean absolute percentage error

# %%
mean_absolute_percentage_error(y_test, preds1_2)*100
# Out:
# 9.485998635491962

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds1_2)
# Out:
# 16911.621461187213

# %% [markdown]
# root mean squared error

# %%
root_mean_squared_error(y_test, preds1_2)
# Out:
# 33740.09960376338

# %%
cvmodel.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'sqrt',
#  'min_samples_split': 2,
#  'n_estimators': 150}

# %% [markdown]
# #### Hyperparameter tuning throught Bayestian optimisation

# %%
def objective(trial):
    # Suggest values for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    # Create the model with suggested hyperparameters
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    # Evaluate the model using cross-validation
    score = cross_val_score(model, scaled_X_train, y_train, cv=5, scoring='neg_root_mean_squared_error').mean()
    print(score)

    # Return the negative score (Optuna minimizes by default)
    return score

study = optuna.create_study(direction='maximize')  # Minimize the objective function
study.optimize(objective, n_trials=150)  # Perform 150 trials

# Print the best hyperparameters and score
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2025-02-28 08:48:13,282] A new study created in memory with name: no-name-02c102aa-bc5a-42d4-83aa-2c231a7d0ded
# [I 2025-02-28 08:48:22,656] Trial 0 finished with value: -31872.18758271038 and parameters: {'n_estimators': 166, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 0 with value: -31872.18758271038.
# -31872.18758271038
# [I 2025-02-28 08:48:24,082] Trial 1 finished with value: -35755.72915437948 and parameters: {'n_estimators': 94, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 0 with value: -31872.18758271038.
# -35755.72915437948
# [I 2025-02-28 08:48:27,377] Trial 2 finished with value: -29561.949626234797 and parameters: {'n_estimators': 163, 'max_depth': 20, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 2 with value: -29561.949626234797.
# -29561.949626234797
# [I 2025-02-28 08:48:28,871] Trial 3 finished with value: -34921.931056636895 and parameters: {'n_estimators': 133, 'max_depth': 28, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 2 with value: -29561.949626234797.
# -34921.931056636895
# [I 2025-02-28 08:48:31,131] Trial 4 finished with value: -30757.8487332738 and parameters: {'n_estimators': 160, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt'}. Best is trial 2 with value: -29561.949626234797.
# -30757.8487332738
# [I 2025-02-28 08:48:35,815] Trial 5 finished with value: -31141.276652046443 and parameters: {'n_estimators': 295, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 4, 'max_features': 'sqrt'}. Best is trial 2 with value: -29561.949626234797.
# -31141.276652046443
# [I 2025-02-28 08:48:39,517] Trial 6 finished with value: -31647.556840214907 and parameters: {'n_estimators': 278, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 2 with value: -29561.949626234797.
# -31647.556840214907
# [I 2025-02-28 08:48:41,046] Trial 7 finished with value: -34097.10106927519 and parameters: {'n_estimators': 133, 'max_depth': 12, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 2 with value: -29561.949626234797.
# -34097.10106927519
# [I 2025-02-28 08:49:01,342] Trial 8 finished with value: -29230.543337190455 and parameters: {'n_estimators': 204, 'max_depth': 29, 'min_samples_split': 9, 'min_samples_leaf': 3, 'max_features': None}. Best is trial 8 with value: -29230.543337190455.
# -29230.543337190455
# [I 2025-02-28 08:49:02,012] Trial 9 finished with value: -40258.275657794 and parameters: {'n_estimators': 70, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2'}. Best is trial 8 with value: -29230.543337190455.
# -40258.275657794
# [I 2025-02-28 08:49:28,486] Trial 10 finished with value: -28894.63546014973 and parameters: {'n_estimators': 236, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 10 with value: -28894.63546014973.
# -28894.63546014973
# [I 2025-02-28 08:49:55,713] Trial 11 finished with value: -28896.248724028927 and parameters: {'n_estimators': 240, 'max_depth': 30, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': None}. Best is trial 10 with value: -28894.63546014973.
# -28896.248724028927

# %%
best_params = study.best_params

final_model = RandomForestRegressor(**best_params, random_state=42)
final_model.fit(scaled_X_train, y_train)

preds1_3 = final_model.predict(scaled_X_test)

# %%
best_params

# %% [markdown]
# mean absolute percentage error

# %%
mean_absolute_percentage_error(y_test, preds1_3)*100

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds1_3)

# %% [markdown]
# root mean squared error

# %%
root_mean_squared_error(y_test, preds1_3)

# %% [markdown]
# #### Conclusion

# %% [markdown]
# We got about the same mean percentage error (about 9.5 percent : 16747 euros) regardless of the the presence of hyperparameter optimisation of its method

# %%
root_mean_squared_error(y_test, preds1_1)

# %%
np.std(y_test)

# %% [markdown]
# a "best guess" model would always guess the mean price as the price of a house.
#
# - the root_mean_square_error of our "best guess" model would be the standard deviation (sum of square differences between price and mean). In this case, it is equal to 95 585 euros
#
# - the root_mean_square_error of our Random Forest model is 30 830 euros.
#
# Therefore, our model "divides by 3" the "best guess" error (kind of)

# %% [markdown]
# #### Get feature importances (the code is executed in the data cleaning section)
#
# Creation of a new version of the feature set that involves only the most relevant features according to the random forest regressor model (dimentionnality reduction)

# %%
# pass

# %% [markdown]
# ### Model 2 : Ordinary Least Square Regression (Classical) [mape = 11.91%, rmse = 33973]

# %% [markdown]
# Because we noticed that Linear Regression can hallucinate with predictions when the data is categorical, we will use only numerical features

# %%
get_best_regression_degree(numer_scaled_X_train, y_train, LinearRegression(), range=range(1, 4))
# Out:
#  degree in process :  1
# number of features :  50
# mean_absolute_percentage_error (mean CV):  0.12168906461058829
# mean_absolute_percentage_error (on the training set) :  0.11443557719033037
#
#  degree in process :  2
# number of features :  1325
# mean_absolute_percentage_error (mean CV):  232829107.9468553
# mean_absolute_percentage_error (on the training set) :  0.03309592178644089
#
#  degree in process :  3
# number of features :  23425
# mean_absolute_percentage_error (mean CV):  0.16282887322719372
# mean_absolute_percentage_error (on the training set) :  9.953116633205748e-15
# (0, -0.16282887322719372)

# %%
lr = LinearRegression()

lr.fit(numer_scaled_X_train, y_train)
preds2 = lr.predict(numer_scaled_X_test)

mape = mean_absolute_percentage_error(y_test, preds2)
rmse = root_mean_squared_error(y_test, preds2)

# %% [markdown]
# mean absolute percentage error

# %%
mape
# Out:
# 0.11915062531206491

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds2)
# Out:
# 20491.733571849883

# %% [markdown]
# root mean squared error

# %%
rmse
# Out:
# 33973.85496614337

# %% [markdown]
# ### Model 3 : Ordinary Least Square Regression (ElasticNet) [mape = 9.9%, rmse = 33865]

# %% [markdown]
# Elastic net handle better categorical features, so we will inclue them in the dataset

# %%
elastic_model = ElasticNetCV(l1_ratio=[.1, .5, .7,.9, .95, .99, 1],tol=0.01)

elastic_model.fit(scaled_X_train, y_train)
preds3 = elastic_model.predict(scaled_X_test)

# %% [markdown]
# mean percentage absolute error

# %%
mean_absolute_error(y_test, preds3)
# Out:
# 0.09899025062480972

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds3)

# %% [markdown]
# root mean squared error

# %%
root_mean_squared_error(y_test, preds3)
# Out:
# 33864.83243874577

# %% [markdown]
# ### Model 4 : Support Vector Machines Regressor [mape = 10.83%, rmse = 33420]

# %% [markdown]
# #### No hyperparameter optimisation (default hyperparameters)

# %%
svr = SVR()
svr.fit(numer_scaled_X_train, y_train)
preds4_1 = svr.predict(numer_scaled_X_test)
mape = mean_absolute_percentage_error(y_test, preds4_1)
rmse = root_mean_squared_error(y_test, preds4_1)

# %% [markdown]
# mean absolute percentage error

# %%
print(mape)
# Out:
# 0.35707795592603614

# %% [markdown]
# mean absolute error

# %%
print(mean_absolute_error(y_test, preds4_1))
# Out:
# 62935.61259521903

# %% [markdown]
# root mean squared error

# %%
print(rmse)
# Out:
# 97291.368633669

# %% [markdown]
# #### Hyperparameter optimisation through GridSearchCV

# %% [markdown]
# - scaled_X_train
# - numer_scaled_X_train
# - scaled_topfi_X_train

# %%
svr = SVR()

param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}

svrcv = GridSearchCV(svr, param_grid, cv=5, scoring='neg_root_mean_squared_error', verbose=5)
svrcv.fit(scaled_topfi_X_train, y_train)
preds4_2 = svrcv.predict(scaled_topfi_X_test)
mape = mean_absolute_percentage_error(y_test, preds4_2)
rmse = root_mean_squared_error(y_test, preds4_2)

# %% [markdown]
# mean absolute percentage error

# %%
mape
# Out:
# 0.10949567744884964

# %% [markdown]
# mean absolute error

# %%
mean_absolute_error(y_test, preds4_2)
# Out:
# 20662.626518697554

# %% [markdown]
# root mean squared error

# %%
rmse
# Out:
# 39688.87299462439

# %% [markdown]
# #### Hyperparameter optimization through Bayesian Search

# %%
np.int = int

# %%
# Define the RMSE threshold
threshold_rmse = -25000

def stop_if_rmse_below_threshold(result):
    # Since higher negative RMSE values are better, we take the maximum.
    best_neg_rmse = np.max(result.func_vals)
    # Convert it to positive RMSE
    best_rmse = -best_neg_rmse
    print(f"Current best RMSE: {best_rmse:.4f}")
    if best_rmse <= threshold_rmse:
        print(f"Stopping early: achieved RMSE {best_rmse:.4f} <= threshold {threshold_rmse}")
        return True  # Signals early stopping
    return False


params = {
         'C': Real(1e-6, 1e+6, prior='log-uniform'),
         'gamma': Real(1e-6, 1e+1, prior='log-uniform'),
         'degree': Integer(1,8),
         'kernel': Categorical(['linear', 'poly', 'rbf']),
     }

opt = BayesSearchCV(SVR(), params, n_iter=100, random_state=0, verbose=5, scoring='neg_root_mean_squared_error', cv=5, refit=True)

opt.fit(scaled_topfi_X_train, y_train)
# opt.save('baysian_optimized_SVM_on_housing_prices.h5')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=2.352718564818733, degree=6, gamma=0.022854318128961743, kernel=poly;, score=-75083.867 total time=   0.2s
# [CV 2/5] END C=2.352718564818733, degree=6, gamma=0.022854318128961743, kernel=poly;, score=-87700.934 total time=   0.2s
# [CV 3/5] END C=2.352718564818733, degree=6, gamma=0.022854318128961743, kernel=poly;, score=-85589.375 total time=   0.2s
# [CV 4/5] END C=2.352718564818733, degree=6, gamma=0.022854318128961743, kernel=poly;, score=-72438.999 total time=   0.3s
# [CV 5/5] END C=2.352718564818733, degree=6, gamma=0.022854318128961743, kernel=poly;, score=-74072.324 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.0012602593949011189, degree=8, gamma=2.285959941576884, kernel=poly;, score=-1494050.574 total time=   1.5s
# [CV 2/5] END C=0.0012602593949011189, degree=8, gamma=2.285959941576884, kernel=poly;, score=-40722394.313 total time=   1.2s
# [CV 3/5] END C=0.0012602593949011189, degree=8, gamma=2.285959941576884, kernel=poly;, score=-170536148.754 total time=   1.4s
# [CV 4/5] END C=0.0012602593949011189, degree=8, gamma=2.285959941576884, kernel=poly;, score=-40412214.622 total time=   1.6s
# [CV 5/5] END C=0.0012602593949011189, degree=8, gamma=2.285959941576884, kernel=poly;, score=-2331620.467 total time=   1.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=2.2095350994035026, degree=1, gamma=0.0002488766453161173, kernel=linear;, score=-64355.289 total time=   0.1s
# [CV 2/5] END C=2.2095350994035026, degree=1, gamma=0.0002488766453161173, kernel=linear;, score=-76074.284 total time=   0.1s
# [CV 3/5] END C=2.2095350994035026, degree=1, gamma=0.0002488766453161173, kernel=linear;, score=-73844.383 total time=   0.1s
# [CV 4/5] END C=2.2095350994035026, degree=1, gamma=0.0002488766453161173, kernel=linear;, score=-62771.878 total time=   0.1s
# [CV 5/5] END C=2.2095350994035026, degree=1, gamma=0.0002488766453161173, kernel=linear;, score=-63291.012 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=5.87540411933884e-05, degree=6, gamma=0.001948086705393068, kernel=poly;, score=-75084.163 total time=   0.2s
# [CV 2/5] END C=5.87540411933884e-05, degree=6, gamma=0.001948086705393068, kernel=poly;, score=-87753.886 total time=   0.1s
# [CV 3/5] END C=5.87540411933884e-05, degree=6, gamma=0.001948086705393068, kernel=poly;, score=-84585.075 total time=   0.1s
# [CV 4/5] END C=5.87540411933884e-05, degree=6, gamma=0.001948086705393068, kernel=poly;, score=-73689.351 total time=   0.2s
# [CV 5/5] END C=5.87540411933884e-05, degree=6, gamma=0.001948086705393068, kernel=poly;, score=-74079.003 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.0006168340492440594, degree=3, gamma=0.1251031728258015, kernel=poly;, score=-75081.741 total time=   0.1s
# [CV 2/5] END C=0.0006168340492440594, degree=3, gamma=0.1251031728258015, kernel=poly;, score=-87751.097 total time=   0.3s
# [CV 3/5] END C=0.0006168340492440594, degree=3, gamma=0.1251031728258015, kernel=poly;, score=-84581.474 total time=   0.1s
# [CV 4/5] END C=0.0006168340492440594, degree=3, gamma=0.1251031728258015, kernel=poly;, score=-73686.513 total time=   0.1s
# [CV 5/5] END C=0.0006168340492440594, degree=3, gamma=0.1251031728258015, kernel=poly;, score=-74076.721 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=11428.693628355693, degree=8, gamma=0.13609648966949792, kernel=poly;, score=-1465354.621 total time=   1.2s
# [CV 2/5] END C=11428.693628355693, degree=8, gamma=0.13609648966949792, kernel=poly;, score=-43084657.419 total time=   1.5s
# [CV 3/5] END C=11428.693628355693, degree=8, gamma=0.13609648966949792, kernel=poly;, score=-291036200.410 total time=   1.6s
# [CV 4/5] END C=11428.693628355693, degree=8, gamma=0.13609648966949792, kernel=poly;, score=-39915419.407 total time=   1.4s
# [CV 5/5] END C=11428.693628355693, degree=8, gamma=0.13609648966949792, kernel=poly;, score=-1559915.073 total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=403250.2994939669, degree=6, gamma=0.0009731446660936579, kernel=linear;, score=-29644.300 total time=  10.3s
# [CV 2/5] END C=403250.2994939669, degree=6, gamma=0.0009731446660936579, kernel=linear;, score=-40225.693 total time=   6.3s
# [CV 3/5] END C=403250.2994939669, degree=6, gamma=0.0009731446660936579, kernel=linear;, score=-50682.415 total time=  13.0s
# [CV 4/5] END C=403250.2994939669, degree=6, gamma=0.0009731446660936579, kernel=linear;, score=-29786.968 total time=10.8min
# [CV 5/5] END C=403250.2994939669, degree=6, gamma=0.0009731446660936579, kernel=linear;, score=-27190.814 total time=   5.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1.3361910455737007, degree=5, gamma=0.11283439533114079, kernel=linear;, score=-68447.246 total time=   0.0s
# [CV 2/5] END C=1.3361910455737007, degree=5, gamma=0.11283439533114079, kernel=linear;, score=-80486.026 total time=   0.0s
# [CV 3/5] END C=1.3361910455737007, degree=5, gamma=0.11283439533114079, kernel=linear;, score=-77849.778 total time=   0.0s
# [CV 4/5] END C=1.3361910455737007, degree=5, gamma=0.11283439533114079, kernel=linear;, score=-66880.548 total time=   0.0s
# [CV 5/5] END C=1.3361910455737007, degree=5, gamma=0.11283439533114079, kernel=linear;, score=-67495.090 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1.272488783429722e-05, degree=7, gamma=0.35840521681314447, kernel=rbf;, score=-75084.163 total time=   0.1s
# [CV 2/5] END C=1.272488783429722e-05, degree=7, gamma=0.35840521681314447, kernel=rbf;, score=-87753.886 total time=   0.1s
# [CV 3/5] END C=1.272488783429722e-05, degree=7, gamma=0.35840521681314447, kernel=rbf;, score=-84585.075 total time=   0.1s
# [CV 4/5] END C=1.272488783429722e-05, degree=7, gamma=0.35840521681314447, kernel=rbf;, score=-73689.351 total time=   0.1s
# [CV 5/5] END C=1.272488783429722e-05, degree=7, gamma=0.35840521681314447, kernel=rbf;, score=-74079.003 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.027192161365809257, degree=4, gamma=6.79471779184038e-05, kernel=rbf;, score=-75084.146 total time=   0.1s
# [CV 2/5] END C=0.027192161365809257, degree=4, gamma=6.79471779184038e-05, kernel=rbf;, score=-87753.868 total time=   0.1s
# [CV 3/5] END C=0.027192161365809257, degree=4, gamma=6.79471779184038e-05, kernel=rbf;, score=-84585.054 total time=   0.1s
# [CV 4/5] END C=0.027192161365809257, degree=4, gamma=6.79471779184038e-05, kernel=rbf;, score=-73689.331 total time=   0.1s
# [CV 5/5] END C=0.027192161365809257, degree=4, gamma=6.79471779184038e-05, kernel=rbf;, score=-74078.985 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0008911865329829303, kernel=linear;, score=-29644.597 total time=   6.4s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0008911865329829303, kernel=linear;, score=-40225.370 total time=   4.8s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0008911865329829303, kernel=linear;, score=-50687.748 total time=   7.1s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.0008911865329829303, kernel=linear;, score=-29785.744 total time=   4.9s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.0008911865329829303, kernel=linear;, score=-27192.858 total time=   6.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0008681744186465924, kernel=linear;, score=-29644.597 total time=   6.0s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0008681744186465924, kernel=linear;, score=-40225.370 total time=   5.6s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0008681744186465924, kernel=linear;, score=-50687.748 total time=   7.0s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.0008681744186465924, kernel=linear;, score=-29785.744 total time=   5.2s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.0008681744186465924, kernel=linear;, score=-27192.858 total time=   5.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=0.01178903402281403, degree=6, gamma=0.006676686691401733, kernel=poly;, score=-75084.163 total time=   0.0s
# [CV 2/5] END C=0.01178903402281403, degree=6, gamma=0.006676686691401733, kernel=poly;, score=-87753.890 total time=   0.0s
# [CV 3/5] END C=0.01178903402281403, degree=6, gamma=0.006676686691401733, kernel=poly;, score=-84585.072 total time=   0.0s
# [CV 4/5] END C=0.01178903402281403, degree=6, gamma=0.006676686691401733, kernel=poly;, score=-73689.345 total time=   0.0s
# [CV 5/5] END C=0.01178903402281403, degree=6, gamma=0.006676686691401733, kernel=poly;, score=-74079.003 total time=   0.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.000810025633256543, kernel=linear;, score=-29644.597 total time=   5.9s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.000810025633256543, kernel=linear;, score=-40225.370 total time=   5.4s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.000810025633256543, kernel=linear;, score=-50687.748 total time=   6.7s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.000810025633256543, kernel=linear;, score=-29785.744 total time=   5.6s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.000810025633256543, kernel=linear;, score=-27192.858 total time=   5.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=4.27773959972655e-06, degree=7, gamma=0.33223410455421604, kernel=rbf;, score=-75084.163 total time=   0.1s
# [CV 2/5] END C=4.27773959972655e-06, degree=7, gamma=0.33223410455421604, kernel=rbf;, score=-87753.886 total time=   0.1s
# [CV 3/5] END C=4.27773959972655e-06, degree=7, gamma=0.33223410455421604, kernel=rbf;, score=-84585.075 total time=   0.1s
# [CV 4/5] END C=4.27773959972655e-06, degree=7, gamma=0.33223410455421604, kernel=rbf;, score=-73689.351 total time=   0.1s
# [CV 5/5] END C=4.27773959972655e-06, degree=7, gamma=0.33223410455421604, kernel=rbf;, score=-74079.003 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0007915133594882424, kernel=linear;, score=-29644.597 total time=   6.0s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0007915133594882424, kernel=linear;, score=-40225.370 total time=   5.4s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0007915133594882424, kernel=linear;, score=-50687.748 total time=   6.7s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.0007915133594882424, kernel=linear;, score=-29785.744 total time=   5.4s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.0007915133594882424, kernel=linear;, score=-27192.858 total time=   5.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0007886016106523821, kernel=linear;, score=-29644.597 total time=   6.5s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0007886016106523821, kernel=linear;, score=-40225.370 total time=   4.9s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0007886016106523821, kernel=linear;, score=-50687.748 total time=   7.2s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.0007886016106523821, kernel=linear;, score=-29785.744 total time=   4.9s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.0007886016106523821, kernel=linear;, score=-27192.858 total time=   6.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=902723.0286436249, degree=6, gamma=5.87865558517409e-05, kernel=linear;, score=-29644.548 total time=   3.7s
# [CV 2/5] END C=902723.0286436249, degree=6, gamma=5.87865558517409e-05, kernel=linear;, score=-40225.422 total time=   6.4s
# [CV 3/5] END C=902723.0286436249, degree=6, gamma=5.87865558517409e-05, kernel=linear;, score=-50685.771 total time=   9.1s
# [CV 4/5] END C=902723.0286436249, degree=6, gamma=5.87865558517409e-05, kernel=linear;, score=-29785.943 total time=   5.9s
# [CV 5/5] END C=902723.0286436249, degree=6, gamma=5.87865558517409e-05, kernel=linear;, score=-27192.526 total time=   4.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=861751.5708401006, degree=6, gamma=0.00012435896012387326, kernel=linear;, score=-29644.527 total time=   3.5s
# [CV 2/5] END C=861751.5708401006, degree=6, gamma=0.00012435896012387326, kernel=linear;, score=-40225.444 total time=   6.0s
# [CV 3/5] END C=861751.5708401006, degree=6, gamma=0.00012435896012387326, kernel=linear;, score=-50684.938 total time=   8.1s
# [CV 4/5] END C=861751.5708401006, degree=6, gamma=0.00012435896012387326, kernel=linear;, score=-29786.028 total time=   5.2s
# [CV 5/5] END C=861751.5708401006, degree=6, gamma=0.00012435896012387326, kernel=linear;, score=-27192.383 total time=   5.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=905112.7357708121, degree=6, gamma=0.00013172536129047455, kernel=linear;, score=-29644.549 total time=   5.0s
# [CV 2/5] END C=905112.7357708121, degree=6, gamma=0.00013172536129047455, kernel=linear;, score=-40225.421 total time=   4.4s
# [CV 3/5] END C=905112.7357708121, degree=6, gamma=0.00013172536129047455, kernel=linear;, score=-50685.820 total time=   8.3s
# [CV 4/5] END C=905112.7357708121, degree=6, gamma=0.00013172536129047455, kernel=linear;, score=-29785.939 total time=   4.9s
# [CV 5/5] END C=905112.7357708121, degree=6, gamma=0.00013172536129047455, kernel=linear;, score=-27192.532 total time=   4.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=954581.4705894205, degree=6, gamma=9.57515378382968e-05, kernel=linear;, score=-29644.574 total time=   4.1s
# [CV 2/5] END C=954581.4705894205, degree=6, gamma=9.57515378382968e-05, kernel=linear;, score=-40225.394 total time=   7.2s
# [CV 3/5] END C=954581.4705894205, degree=6, gamma=9.57515378382968e-05, kernel=linear;, score=-50686.825 total time=   8.0s
# [CV 4/5] END C=954581.4705894205, degree=6, gamma=9.57515378382968e-05, kernel=linear;, score=-29785.837 total time=   4.9s
# [CV 5/5] END C=954581.4705894205, degree=6, gamma=9.57515378382968e-05, kernel=linear;, score=-27192.702 total time=   8.8s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=7.044010735970503e-05, kernel=linear;, score=-29644.597 total time=   6.0s
# [CV 2/5] END C=1000000.0, degree=6, gamma=7.044010735970503e-05, kernel=linear;, score=-40225.370 total time=   5.5s
# [CV 3/5] END C=1000000.0, degree=6, gamma=7.044010735970503e-05, kernel=linear;, score=-50687.748 total time=   7.0s
# [CV 4/5] END C=1000000.0, degree=6, gamma=7.044010735970503e-05, kernel=linear;, score=-29785.744 total time=   5.1s
# [CV 5/5] END C=1000000.0, degree=6, gamma=7.044010735970503e-05, kernel=linear;, score=-27192.858 total time=   5.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=4.3094014316898664e-05, kernel=linear;, score=-29644.597 total time=   6.0s
# [CV 2/5] END C=1000000.0, degree=6, gamma=4.3094014316898664e-05, kernel=linear;, score=-40225.370 total time=   5.4s
# [CV 3/5] END C=1000000.0, degree=6, gamma=4.3094014316898664e-05, kernel=linear;, score=-50687.748 total time=   6.6s
# [CV 4/5] END C=1000000.0, degree=6, gamma=4.3094014316898664e-05, kernel=linear;, score=-29785.744 total time=   5.4s
# [CV 5/5] END C=1000000.0, degree=6, gamma=4.3094014316898664e-05, kernel=linear;, score=-27192.858 total time=   5.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0001030153535588102, kernel=linear;, score=-29644.597 total time=   6.8s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0001030153535588102, kernel=linear;, score=-40225.370 total time=   4.9s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0001030153535588102, kernel=linear;, score=-50687.748 total time=   7.7s
# [CV 4/5] END C=1000000.0, degree=6, gamma=0.0001030153535588102, kernel=linear;, score=-29785.744 total time=   5.9s
# [CV 5/5] END C=1000000.0, degree=6, gamma=0.0001030153535588102, kernel=linear;, score=-27192.858 total time=   6.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5] END C=1000000.0, degree=6, gamma=0.0001737767434188493, kernel=linear;, score=-29644.597 total time=   6.5s
# [CV 2/5] END C=1000000.0, degree=6, gamma=0.0001737767434188493, kernel=linear;, score=-40225.370 total time=   4.8s
# [CV 3/5] END C=1000000.0, degree=6, gamma=0.0001737767434188493, kernel=linear;, score=-50687.748 total time=   7.2s

# %%
preds4_3 = opt.predict(scaled_topfi_X_test)

# %%
root_mean_squared_error(y_test, preds4_3)
# Out:
# 39696.925718855375

# %% [markdown]
# ### Model 5 : KNN Regressor [mape = 9.90%, rmse = 33864]

# %% [markdown]
# We do hyperparameter tuning by displaying the graph of the error of the model for each k value, so that we choose k that show the lowest error (k representing the number of nearest neibors considered for predictions)

# %% [markdown]
# Unlike other models, knn is very sensitive to the relevance of the features for y predicitions. Therefore, it is interesting to see with what version of the dataset will it perform the best. We will not display all the trials, but here is a ranking of the feature set version in terms of error metrics, from the worse to the best :
# - X_train
# - scaled_X_train
# - numer_scaled_X_train
# - scaled_topfi_X_train
# - scaled_topfi_scaletopfi_X_test

# %%
scaled_topfi_scaletopfi_X_train = scaled_topfi_X_train.copy()
scaled_topfi_scaletopfi_X_train *= np.sqrt(np.array(fi[1][:25]).tolist())

scaled_topfi_scaletopfi_X_test = scaled_topfi_X_test.copy()
scaled_topfi_scaletopfi_X_test *= np.sqrt(np.array(fi[1][:25]).tolist())

# %%
test_error_rates_uni = []


for k in range(1,30):

    knn = KNeighborsRegressor(n_neighbors=k)

    score = cross_val_score(knn, scaled_topfi_scaletopfi_X_train, y_train, cv=5, scoring='neg_mean_absolute_percentage_error').mean()
    error = -score

    test_error_rates_uni.append(error)

# %%
test_error_rates_dist = []


for k in range(1,30):

    knn = KNeighborsRegressor(n_neighbors=k, weights='distance')

    score = cross_val_score(knn, scaled_topfi_scaletopfi_X_train, y_train, cv=5, scoring='neg_mean_absolute_percentage_error').mean()
    error = -score

    test_error_rates_dist.append(error)

# %%
plt.figure(figsize=(5,3),dpi=200)
plt.plot(range(1,30),test_error_rates_uni,label='Test Error for weight = uniform')

plt.plot(range(1,30),test_error_rates_dist,label='Test Error for weight = distance')

plt.legend()
plt.ylabel('Error Rate')
plt.xlabel("K Value")
plt.show()

# %%
model = KNeighborsRegressor(n_neighbors=10, weights = 'distance')

# %%
model.fit(scaled_topfi_scaletopfi_X_train, y_train)
preds5 = model.predict(scaled_topfi_scaletopfi_X_test)
mape = mean_absolute_percentage_error(y_test, preds5)
rmse = root_mean_squared_error(y_test, preds5)

# %% [markdown]
# root mean squared error

# %%
rmse
# Out:
# 34249.04579602127

# %% [markdown]
# mean absolute percentage error

# %%
mape
# Out:
# 0.10265763992343671

# %% [markdown]
# ### Model 6 : Categorical boosting [mape = 8.05%, rmse = 27168] (our best model)

# %% [markdown]
# **Categorical boosting is very useful in that case for two reasons :**
#
# There is no need to do any data preprocessing
# - *no need to deal with missing values*
# - *no need to do one-hot encoding (witch increases the complexity of our data as we come out with 260 features)*
#
# Cat boost is known to work very well when there are a many features (80 features in our case)

# %% [markdown]
# **We still need to do two things before giving the data to our model :**
#
# 1) delete the Id features (meaningless feature)
#
# 2) Make MSSubClass categorical (The data documentations tell us that it was originally categorical but they converted it to numerical for whatever reason)

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
MSSubClass_dict =  {20  :  '1-STORY 1946 & NEWER ALL STYLES',
                    30  :  '1-STORY 1945 & OLDER',
                    40  :  '1-STORY W/FINISHED ATTIC ALL AGES',
                    45  :  '1-1/2 STORY - UNFINISHED ALL AGES',
                    50  :  '1-1/2 STORY FINISHED ALL AGES',
                    60  :  '2-STORY 1946 & NEWER',
                    70  :  '2-STORY 1945 & OLDER',
                    75  :  '2-1/2 STORY ALL AGES',
                    80  :  'SPLIT OR MULTI-LEVEL',
                    85  :  'SPLIT FOYER',
                    90  :  'DUPLEX - ALL STYLES AND AGES',
                    120  :  '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
                    150  :  '1-1/2 STORY PUD - ALL AGES',
                    160  :  '2-STORY PUD - 1946 & NEWER',
                    180  :  'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
                    190  :  '2 FAMILY CONVERSION - ALL STYLES AND AGES'
                    }

df['MSSubClass'] = df['MSSubClass'].apply(lambda n: MSSubClass_dict[n])

# %%
X, y = df.drop(['SalePrice', 'Id'], axis=1), df['SalePrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

categorical_features = [
    'MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
    'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
    'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
    'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
    'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
    'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
    'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'
]

# Convert categorical columns to string format (if not already)
X_train[categorical_features] = X_train[categorical_features].astype(str)
X_test[categorical_features] = X_test[categorical_features].astype(str)

# Create a CatBoost Pool (optional but recommended)
train_pool = Pool(X_train, y_train, cat_features = categorical_features)

# Initialize and train the model
catmodel = CatBoostRegressor(verbose=200)

catmodel.fit(train_pool)

catpreds = catmodel.predict(X_test)
print('MAPE : ', mean_absolute_percentage_error(y_test, catpreds))
print('MAE : ', mean_absolute_error(y_test, catpreds))
print('RMSE : ', root_mean_squared_error(y_test, catpreds))
# Out:
# Learning rate set to 0.042748
# 0:	learn: 75250.5739087	total: 27.4ms	remaining: 27.3s
# 200:	learn: 17705.1437410	total: 7.8s	remaining: 31s
# 400:	learn: 13831.6958989	total: 17.2s	remaining: 25.6s
# 600:	learn: 11627.3480062	total: 23.7s	remaining: 15.7s
# 800:	learn: 9993.7268510	total: 32s	remaining: 7.95s
# 999:	learn: 8593.8187532	total: 38.5s	remaining: 0us
# MAPE :  0.08059256071781737
# MAE :  14819.546085334625
# RMSE :  27168.302885698315

# %% [markdown]
# ## Expected error visualisation

# %%
comparison = pd.DataFrame(data={'prices' : y_test.values, 'preds': catpreds}).sort_values(by='prices')

# %%
comparison.index = range(len(comparison))

# %%
comparison.head()
# Out:
#    prices         preds
# 0   35311  69502.216334
# 1   60000  45736.936516
# 2   67000  64606.355389
# 3   68500  73165.059595
# 4   75500  76821.687898

# %%
errors = catpreds - y_test
sns.kdeplot(errors)
plt.title('Error distribution (Predictions-ActualPrice difference on test data)')
errors.std()
# Out:
# 27224.670606429565

# %%
# plt.figure(figsize=(12, 6))

# plt.plot(comparison.index, comparison['prices'], label="Actual Prices", color='b')
# plt.scatter(comparison.index, comparison['preds'], s=20, color='orange', label="Predictions")

# plt.legend()
# plt.show()

plt.figure(figsize=(12, 6))

# Plot actual prices as a line
plt.plot(comparison.index, comparison['prices'], label="Actual Prices", color='b')

# Draw vertical lines showing the difference between actual prices and predictions
plt.vlines(
    x=comparison.index,
    ymin=comparison['preds'],
    ymax=comparison['prices'],
    color='orange',
    linewidth=2
)

# Add a legend
plt.xlabel('Prediction number (in increasing order according to price)')
plt.ylabel('Prices in euros')

plt.legend(["Actual Prices", 'gaps with predicted price'])
plt.show()

# %%
root_mean_squared_error(y_test, catpreds)
# Out:
# 27168.302885698315

# %%
mean_absolute_error(y_test, catpreds)
# Out:
# 14819.546085334625

# %%
plt.figure(figsize=(12, 6))

y.plot(kind='kde')

plt.gca().ticklabel_format(style='plain', axis='x')
plt.xticks(np.arange(0, 600000, 10000), rotation=90)
plt.xlim(0, 600000)
plt.grid(axis='x', linestyle='--', color='gray', alpha=0.7)
mean_value = y.mean()
plt.axvline(mean_value, color='blue', linestyle='--', linewidth=1.5, label=f'Mean House price = {mean_value:.0f}')

mae = mean_absolute_error(y_test, catpreds)
confidence_80 = root_mean_squared_error(y_test, catpreds)*1.282
confidence_95 = root_mean_squared_error(y_test, catpreds)*2

y_middle = plt.gca().get_ylim()[1] / 2
y_lower = y_middle - 10**-6
y_lower2 = y_lower - 10**-6

plt.annotate('mean absolute error', xy=(mean_value, y_middle+10**-7),
             xytext=(mean_value + mae, y_middle+10**-7),
             arrowprops=dict(arrowstyle='<|-', color='blue', lw=0.5))

plt.annotate('                   ', xy=(mean_value - mae, y_middle+10**-7),
             xytext=(mean_value, y_middle-10**-7),
             arrowprops=dict(arrowstyle='-|>', color='blue', lw=0.5))

plt.annotate('80% CI',
             xy=(mean_value - confidence_80, y_lower),
             xytext=(mean_value + confidence_80, y_lower),
             arrowprops=dict(arrowstyle='<|-|>', color='red', lw=0.5))

plt.annotate('95% CI',
             xy=(mean_value - confidence_95, y_lower2),
             xytext=(mean_value + confidence_95, y_lower2),
             arrowprops=dict(arrowstyle='<|-|>', color='red', lw=0.5))

plt.xlabel("Actual House Prices")
plt.title("distribution of actual house prices + prediction expected errors")
plt.legend()

plt.show()

# %% [markdown]
# ## Final Predictions for kaggle

# %% [markdown]
# training model on all training data (no portion left for test)

# %%
df = pd.read_csv('train.csv')
X, y = df.drop(['SalePrice', 'Id'], axis=1), df['SalePrice']

# %%
X_final_test_before_cleaning = pd.read_csv('test.csv')
id_serie = X_final_test_before_cleaning.Id
X_final_test_before_cleaning = X_final_test_before_cleaning.drop('Id', axis=1)

# %%
MSSubClass_dict =  {20  :  '1-STORY 1946 & NEWER ALL STYLES',
                    30  :  '1-STORY 1945 & OLDER',
                    40  :  '1-STORY W/FINISHED ATTIC ALL AGES',
                    45  :  '1-1/2 STORY - UNFINISHED ALL AGES',
                    50  :  '1-1/2 STORY FINISHED ALL AGES',
                    60  :  '2-STORY 1946 & NEWER',
                    70  :  '2-STORY 1945 & OLDER',
                    75  :  '2-1/2 STORY ALL AGES',
                    80  :  'SPLIT OR MULTI-LEVEL',
                    85  :  'SPLIT FOYER',
                    90  :  'DUPLEX - ALL STYLES AND AGES',
                    120  :  '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
                    150  :  '1-1/2 STORY PUD - ALL AGES',
                    160  :  '2-STORY PUD - 1946 & NEWER',
                    180  :  'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
                    190  :  '2 FAMILY CONVERSION - ALL STYLES AND AGES'
                    }

X['MSSubClass'] = X['MSSubClass'].apply(lambda n: MSSubClass_dict[n])
X_final_test_before_cleaning['MSSubClass'] = X_final_test_before_cleaning['MSSubClass'].apply(lambda n: MSSubClass_dict[n])

# %%
categorical_features = [
    'MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
    'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
    'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
    'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
    'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
    'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
    'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'
]

# Convert categorical columns to string format (if not already)
X[categorical_features] = X[categorical_features].astype(str)
X_final_test_before_cleaning[categorical_features] = X_final_test_before_cleaning[categorical_features].astype(str)

# Create a CatBoost Pool (optional but recommended)
train_pool = Pool(X, y, cat_features = categorical_features)

# Initialize and train the model
catmodel = CatBoostRegressor(verbose=200)

catmodel.fit(train_pool)
# Out:
# Learning rate set to 0.043466
# 0:	learn: 77212.6196942	total: 34.2ms	remaining: 34.2s
# 200:	learn: 17716.8816149	total: 6.26s	remaining: 24.9s
# 400:	learn: 14096.8763333	total: 14s	remaining: 20.8s
# 600:	learn: 11802.9896645	total: 20.5s	remaining: 13.6s
# 800:	learn: 10042.1420518	total: 28.2s	remaining: 7s
# 999:	learn: 8886.5296516	total: 34.6s	remaining: 0us

# %%
final_kaggle_preds = catmodel.predict(X_final_test_before_cleaning)

# %%
final_kaggle_preds = pd.DataFrame({'Id' : id_serie, 'SalePrice' : final_kaggle_preds})

# %%
final_kaggle_preds.head()
# Out:
#      Id      SalePrice
# 0  1461  118087.161341
# 1  1462  162411.330367
# 2  1463  187516.362433
# 3  1464  193041.243942
# 4  1465  191848.529847

# %%
final_kaggle_preds.to_csv('final_kaggle_preds.csv', index=False)

# %% [markdown]
# **final kaggle score : 0.12330**
